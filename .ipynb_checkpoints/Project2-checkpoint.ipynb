# %% [markdown]
# ### Welcome to CS 334 spring 2021, Project 2
# ### 01 April, 2021

# %%
# Open parsedata.txt and do some file processing
# This file is same for every .mc file to be processed, so it is done just once at the beginning

filepath = ""
extension = ".txt"
filename = "parsedata" + extension
file = open(filename, "r")

LRtable = []
idx = 0
for line in file:
    lookaheads = line.split('&')
    LRtable.append(lookaheads)   # keep \n for now
    if idx == 38:
        break
    idx +=1
idx = 0
for line in file:
    lookaheads = line.split('&')[1:]         # get rid of the extra numbered row for variables
    LRtable[idx] = LRtable[idx] + lookaheads  # we'll concatenate it with the row of terminals already numbered
    idx +=1
print(LRtable)
# Out:
# [['', 'z', 'i', 'b', 't', ';', 'c', 'v', 'm', 'h', 'o', 'l', 'r', 'd', 'n', 's', 'e', 'w', '$\n', 'P', 'L', 'S', 'D\n'], ['0', 's2', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '1', '', '', '\n'], ['1', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'acc\n', '', '', '', '\n'], ['2', '', 's3', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['3', '', 's4', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['4', '', '', 's5', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['5', '', '', '', '', '', 's8', '', 's9', 's10', 's11', 's12', 's13', '', '', '', '', '', '\n', '', '6', '7', '\n'], ['6', '', '', '', 's14', '', 's8', '', 's9', 's10', 's11', 's12', 's13', '', '', '', '', '', '\n', '', '', '15', '\n'], ['7', '', '', '', '', 's16', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['8', '', '', '', '', '', '', 's17', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['9', '', '', '', '', '', '', 's18', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['10', '', 's19', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['11', '', '', '', '', '', '', 's20', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['12', '', '', '', '', '', '', 's21', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['13', '', 's22', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['14', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'r1\n', '', '', '', '\n'], ['15', '', '', '', '', 's23', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['16', '', '', '', 'r2', '', 'r2', '', 'r2', 'r2', 'r2', 'r2', 'r2', 'r2', '', '', '', '', '\n', '', '', '', '\n'], ['17', '', 's24', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['18', '', 's25', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['19', '', 's26', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['20', '', 's27', '', '', 'r7', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['21', '', '', '', '', 'r9', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['22', '', '', '', '', '', 's8', '', 's9', 's10', 's11', 's12', 's13', '', '', '', '', '', '\n', '', '28', '7', '\n'], ['23', '', '', '', 'r3', '', 'r3', '', 'r3', 'r3', 'r3', 'r3', 'r3', 'r3', '', '', '', '', '\n', '', '', '', '\n'], ['24', '', 's29', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['25', '', 's30', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['26', '', '', '', '', 'r6', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['27', '', '', '', '', 'r8', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['28', '', '', '', '', '', 's8', '', 's9', 's10', 's11', 's12', 's13', 's31', '', '', '', '', '\n', '', '', '15', '\n'], ['29', '', '', '', '', '', '', '', '', '', '', '', '', '', 's33', 's34', 's35', 's36', '\n', '', '', '', '32\n'], ['30', '', '', '', '', '', '', '', '', '', '', '', '', '', 's33', 's34', 's35', 's36', '\n', '', '', '', '37\n'], ['31', '', '', '', '', 'r10', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['32', '', '', '', '', 'r4', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['33', '', '', '', '', 'r11', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['34', '', '', '', '', 'r12', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['35', '', '', '', '', 'r13', '', '', '', '', '', '', '', '', '', '', '', '', '\n', '', '', '', '\n'], ['36', '', '', '', '', 'r14', '', '', '', '', '', '', '', '', '', '', '' ...

# %%
# Get rid of the newlines
n = LRtable[0].index('$\n')
for i in range(len(LRtable)):
    withNln =  LRtable[i][-1]
    LRtable[i][-1] = withNln[0:-1]
    withNln2 =  LRtable[i][n]
    LRtable[i][n] = withNln2[0:-1]

print(LRtable[0])
print(LRtable)
# Keep a copy of the table so that I don't have to change the global variable name LRtable
LRtable2 = LRtable.copy()
# Out:
# ['', 'z', 'i', 'b', 't', ';', 'c', 'v', 'm', 'h', 'o', 'l', 'r', 'd', 'n', 's', 'e', 'w', '$', 'P', 'L', 'S', 'D']
# [['', 'z', 'i', 'b', 't', ';', 'c', 'v', 'm', 'h', 'o', 'l', 'r', 'd', 'n', 's', 'e', 'w', '$', 'P', 'L', 'S', 'D'], ['0', 's2', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '1', '', '', ''], ['1', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'acc', '', '', '', ''], ['2', '', 's3', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['3', '', 's4', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['4', '', '', 's5', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['5', '', '', '', '', '', 's8', '', 's9', 's10', 's11', 's12', 's13', '', '', '', '', '', '', '', '6', '7', ''], ['6', '', '', '', 's14', '', 's8', '', 's9', 's10', 's11', 's12', 's13', '', '', '', '', '', '', '', '', '15', ''], ['7', '', '', '', '', 's16', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['8', '', '', '', '', '', '', 's17', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['9', '', '', '', '', '', '', 's18', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['10', '', 's19', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['11', '', '', '', '', '', '', 's20', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['12', '', '', '', '', '', '', 's21', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['13', '', 's22', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['14', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'r1', '', '', '', ''], ['15', '', '', '', '', 's23', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['16', '', '', '', 'r2', '', 'r2', '', 'r2', 'r2', 'r2', 'r2', 'r2', 'r2', '', '', '', '', '', '', '', '', ''], ['17', '', 's24', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['18', '', 's25', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['19', '', 's26', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['20', '', 's27', '', '', 'r7', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['21', '', '', '', '', 'r9', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['22', '', '', '', '', '', 's8', '', 's9', 's10', 's11', 's12', 's13', '', '', '', '', '', '', '', '28', '7', ''], ['23', '', '', '', 'r3', '', 'r3', '', 'r3', 'r3', 'r3', 'r3', 'r3', 'r3', '', '', '', '', '', '', '', '', ''], ['24', '', 's29', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['25', '', 's30', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['26', '', '', '', '', 'r6', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['27', '', '', '', '', 'r8', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['28', '', '', '', '', '', 's8', '', 's9', 's10', 's11', 's12', 's13', 's31', '', '', '', '', '', '', '', '15', ''], ['29', '', '', '', '', '', '', '', '', '', '', '', '', '', 's33', 's34', 's35', 's36', '', '', '', '', '32'], ['30', '', '', '', '', '', '', '', '', '', '', '', '', '', 's33', 's34', 's35', 's36', '', '', '', '', '37'], ['31', '', '', '', '', 'r10', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['32', '', '', '', '', 'r4', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['33', '', '', '', '', 'r11', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['34', '', '', '', '', 'r12', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['35', '', '', '', '', 'r13', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['36', '', '', '', '', 'r14', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['37', '', '', '', '', 'r5', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']]

# %%
# # just ensuring that got rid of the '' as well when no '\n' to remove
print(len(LRtable[0]))
print(len(LRtable[1]))
print(len(LRtable[2]))
# Out:
# 23
# 23
# 23

# %%
# a nice visualization of the table
from tabulate import tabulate
print(tabulate(LRtable))
# Out:
# --  --  ---  --  ---  ---  --  ---  --  ---  ---  ---  ---  ---  ---  ---  ---  ---  ---  -  --  --  --
#     z   i    b   t    ;    c   v    m   h    o    l    r    d    n    s    e    w    $    P  L   S   D
# 0   s2                                                                                    1
# 1                                                                                    acc
# 2       s3
# 3       s4
# 4            s5
# 5                          s8       s9  s10  s11  s12  s13                                   6   7
# 6                s14       s8       s9  s10  s11  s12  s13                                       15
# 7                     s16
# 8                              s17
# 9                              s18
# 10      s19
# 11                             s20
# 12                             s21
# 13      s22
# 14                                                                                   r1
# 15                    s23
# 16               r2        r2       r2  r2   r2   r2   r2   r2
# 17      s24
# 18      s25
# 19      s26
# 20      s27           r7
# 21                    r9
# 22                         s8       s9  s10  s11  s12  s13                                   28  7
# 23               r3        r3       r3  r3   r3   r3   r3   r3
# 24      s29
# 25      s30
# 26                    r6
# 27                    r8
# 28                         s8       s9  s10  s11  s12  s13  s31                                  15
# 29                                                               s33  s34  s35  s36                  32
# 30                                                               s33  s34  s35  s36                  37
# 31                    r10
# 32                    r4
# 33                    r11
# 34                    r12
# 35                    r13
# 36                    r14
# 37                    r5
# --  --  ---  --  ---  ---  --  ---  --  ---  ---  ---  ---  ---  ---  ---  ---  ---  ---  -  --  --  --

# %%
# functions from project 1 -- will not give detailed description again

def valid_int(word, digits):
    try:
        int(word)
    except ValueError:
        return False
    else:
        if word.startswith("0"):
            if len(word) >1:
                return False
        if len(word)>3:
            return False
        return True
    
def valid_variable(word, digits, letters):
    word = list(word)
    digits_in_word = set(word).intersection(set(digits))
    letters_in_word = set(word).intersection(set(letters))
    if (digits_in_word.union(letters_in_word) != set(word)):
        return False                  # foreign symbol outside letters and digits
    if (digits_in_word == set(word)):
        if len(word)<4:        # all digits but length less than 4
            return False
    return True     

def get_token_type(word, digits, letters, keywords, 
              punctuations):
    if ((word in keywords) or (word in punctuations)):
        return (word, "NULL")
    if valid_int(word, digits):
        return ("integer", word)
    if valid_variable(word, digits, letters):
        return ("variable", '0')
    else:
        return ("error", '0')

def comment_starts(wordsList):
    return wordsList.index('//')

def has_comment(wordsList):
    if '//' in wordsList:
        return True
    return False

# %%
'''scanner (main) function from Project 1: the only change made to it were to:

1. Not make entries in the symbol table since we have no use for it (we want to consider all and not only unique tokens)
2. Put each (token type, word (-i.e. token)) identified in program in a list called tuplist
   
Return:
       tupist - list of tuples with strings (token_type, word), where the token is a valid token
       If invalid token is encountered at any point, returns an empty list''' 

def scanner(filename):
    tuplist = []
    file = open(filename, "r")
    line_index = 0
    for line in file:
        words_in_line = line.strip().split(" ")
        if (words_in_line[0] == ''):
            continue
        if has_comment(words_in_line):
            comment_index = comment_starts(words_in_line)
            comment_index -=1
            # ignore white spaces until a non empty character is reached - (correcting error from project 1)
            while(words_in_line[comment_index] == ''):
                comment_index -=1
            # ignore comments:
            words_in_line = words_in_line[0:comment_index+1]
        line_index +=1
        for word in words_in_line:
            word = word.lower()
            (token_type, value) = get_token_type(word, digits, letters, keywords, punctuations)
            if token_type == "error":
                print("error")
                return []
            else:
                tuplist.append((token_type, word)) # a list of the vaild tokens and their characters one by one
                #print("Token is: " + word + ", with token type: " + token_type  + ", and value: " + value + "\n")
    #print(strList)
    return tuplist

# %%
'''Function to return a shortened string version of the cat and mouse program given the list of valid tokens in the program
    This shortened version has only 1-character prefixes of all token types, mostly using first character
    (e.g. 'i' for 'integers') with a few exceptions when non-first characters are chosen for a handful of 
    'special' tokens

Arguments:
          strList - list of strings that are the valid 'token types' found
          specials - token types for whom non-first characters are chosen as their 1-character representation
          shorthands - list of rules dictating which non-first characters to choose for each special token
Return:
       inputStr - the shortened string version of the list of tokens in the cat and mouse program plus a $ added at the end
                    - input to the parser'''
def refine_strList(strList, specials, shorthands):
    inputStr = ''
    for item in strList:
        if item not in specials:
            inputStr += item[0]
        else:
            i = specials.index(item)
            inputStr += shorthands[i]
    return inputStr                      #+'$'

# %%
'''Return: None;
    Just print the parsing stack as it is dynamically updated; and a rule stack, where the rules used to reduce
    tokens are added in the bottom up fashion/ in the reverse order from that used in derivation of program from grammar
Arguments: 
    state - corresponding to rows in the LR parsing table starting from the row labelled 0
    inputStr - a string representing all the valid tokens ina cat and mouse program; 
    each character is the prefix (or a special letter in the middle) of a token
    tokenidx - the index of character in inputStr that is currently the lookahead and is guiding the parsing
    stack - a parsing stack where terminals, variables, and states are temporarily stored by shifting them,
    and eventually popped off by reduction rules
    rulestack - list of tuples of the form (LHS, RHS) corresponding to reduction rules used in parsing input string
    
Global arguments (because they're static):
     ruleToVar - a list of tuples, representing rules of reduction corresponding to entries in the table;
                 the rules in the form: (LHS, RHS); and the index in the list represents the rule number
     LR table - the LR table given, formatted to dimensions 38 by 23'''
     
def handleNextEntry(state, inputStr, tokenidx, stack, rulestack):
    print("stack: ", stack)
    print("token index ", tokenidx)
    print("State, ", state)
    lookahead = '$'
    if tokenidx<len(inputStr):
        lookahead = inputStr[tokenidx]
    print("current lookahead: ", lookahead)
    lookahead_index = lookaheads.index(lookahead)
    print("lookahead index", lookahead_index)
    entry = LRtable[state][lookahead_index]
    print("table entry: ", entry)
    if entry == '':
        print("blank entry on this lookahead = ", lookahead, " with state = ",state, " breaking")
        return
    if entry.startswith('s'):
        stack.append(lookahead)
        next_state = int(entry[1:])
        stack.append(next_state)
        handleNextEntry(next_state, inputStr, tokenidx+1, stack, rulestack)
    elif entry.startswith('r'):
        rule_num = int(entry[1:])
        RHSvar = ruleToVar[rule_num][1]
        LHSvar = ruleToVar[rule_num][0]
        rulestack.append([rule_num, LHSvar, RHSvar])
        for i in range(2*len(RHSvar)):
            print("popping using reduction rule number: ", rule_num, " rule: ", LHSvar, " -> ", RHSvar, " Stack contents: ", stack)
            stack.pop()
        next_state = int(stack[-1]) # before I push the LHS variable, mark which state I was last in
        print("stack after popping: ", stack)
        stack.append(LHSvar)
        print("stack after appending LHS var: ", stack)
        lookahead = stack[-1]
        print("next lookahead: ", lookahead)
        lookahead_index = lookaheads.index(lookahead)
        entry = LRtable[next_state][lookahead_index] # now LHS variable is the lookahead, and the last state is new state; squeezing in the operation that we do at the beginning of the function, to avoid complication/need to change the code further
        stack.append(entry)   # this entry is only a number
        print("stack after appending entry after that lookahead: ", stack)
        next_state = int(stack[-1]) # same as entry
        print("final state of stack after reduction and pushing variable and new state: ", stack)
        handleNextEntry(next_state, inputStr, tokenidx, stack, rulestack)
    elif entry == 'acc':
        print("lookahead is $, stack contents = ", stack, " and entry is ", entry, " so, accept")
        print ("*** VALID PROGRAM ***: program-string can be derived using the grammar")
        print("with rulestack: " , rulestack)
    else:
        print("Encountered blank entry with stack = ", stack, "lookahead ", lookahead, "entry: ", entry )
        print ("*** INVALID PROGRAM ***: not syntactically correct")

# %%
## Set up the input files and global parameters

filepath = "dataproj2/"
#filepath = input("Please enter a filepath + "/", (empty string if same directory as this file): ")

keywords = ["begin", "halt","cat", "mouse", "clockwise", "move", "north", "south", "east", "west", "hole", 
          "repeat", "size", "end"]
punctuations = [";"]               # only ; for now
letters = list("abcdefghijklmnopqrstuvwxyz")
digits = list("0123456789")
specials = ['size', 'move', 'clockwise', 'end', 'halt']
shorthands = ['z', 'o', 'l', 'd', 't']

filename = input("Please enter a filename, (e.g. sample1.mc/ sample2.mc): ")
filename = filepath + filename
# Out:
# Please enter a filename, (e.g. sample1.mc/ sample2.mc): sample2.mc

# %%
# More global variables

LRtable = LRtable2[1:]
lookaheads = LRtable2[0]
print(lookaheads)
ruleToVar = [('P*','P'), ('P', 'ziibLt'), ('L', 'S;'), ('L', 'LS;'), ('S', 'cviiD'), 
             ('S', 'mviid'), ('S', 'hii'), ('S', 'ov'), ('S', 'ovi'), ('S', 'lv'), ('S', 'riLd'),
             ('D', 'n'), ('D', 's'), ('D', 'e'), ('D', 'w')]
rulestack = []
# Out:
# ['', 'z', 'i', 'b', 't', ';', 'c', 'v', 'm', 'h', 'o', 'l', 'r', 'd', 'n', 's', 'e', 'w', '$', 'P', 'L', 'S', 'D']

# %%
'''Main driver function

Arguments:
    filename - the name of the .mc file containing cat and mouse program
Global arguments:
    specials - token types for whom non-first characters are chosen as their 1-character representation
    shorthands - list of rules dictating which non-first characters to choose for each special token
Returns:
    None - calls the SLR(1) parsing algorithm and so prints parsing stack contents, as well as 
            order of use of rules (I have left the rules in the tuple format: (LHS, RHS))'''

def parser(filename, rulestack):
    tuplist = scanner(filename)
    inputStr = ''
    if tuplist !='[]':     
        # print(tuplist)
        strList = [tuplist[k][0] for k in range(len(tuplist))]
        # print(strList)
        inputStr = refine_strList(strList, specials, shorthands)
    else:
        print("INVALID program: has invalid tokens")
    print(inputStr)
    stack = []
    state = 0
    stack.append(state)
    tokenidx = 0
    handleNextEntry(state, inputStr, tokenidx, stack, rulestack)
    for i in range(len(rulestack)):
        ruleidx = rulestack[-i-1][0]
        print("Rule number, rule in right order: ", rulestack[-1-i][0], ruleToVar[ruleidx], "\n")

# %%
parser(filename, rulestack)
# Out:
# ziibcviiw;cviie;mviie;mviin;hii;riov;ov;d;lv;lv;riov;ov;d;rilv;d;ovi;lv;lv;ovi;lv;ovi;lv;ovi;t
# stack:  [0]
# token index  0
# State,  0
# current lookahead:  z
# lookahead index 1
# table entry:  s2
# stack:  [0, 'z', 2]
# token index  1
# State,  2
# current lookahead:  i
# lookahead index 2
# table entry:  s3
# stack:  [0, 'z', 2, 'i', 3]
# token index  2
# State,  3
# current lookahead:  i
# lookahead index 2
# table entry:  s4
# stack:  [0, 'z', 2, 'i', 3, 'i', 4]
# token index  3
# State,  4
# current lookahead:  b
# lookahead index 3
# table entry:  s5
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5]
# token index  4
# State,  5
# current lookahead:  c
# lookahead index 6
# table entry:  s8
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8]
# token index  5
# State,  8
# current lookahead:  v
# lookahead index 7
# table entry:  s17
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17]
# token index  6
# State,  17
# current lookahead:  i
# lookahead index 2
# table entry:  s24
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24]
# token index  7
# State,  24
# current lookahead:  i
# lookahead index 2
# table entry:  s29
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24, 'i', 29]
# token index  8
# State,  29
# current lookahead:  w
# lookahead index 17
# table entry:  s36
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'w', 36]
# token index  9
# State,  36
# current lookahead:  ;
# lookahead index 5
# table entry:  r14
# popping using reduction rule number:  14  rule:  D  ->  w  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'w', 36]
# popping using reduction rule number:  14  rule:  D  ->  w  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'w']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24, 'i', 29]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D']
# next lookahead:  D
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D', '32']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D', '32']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D', '32']
# token index  9
# State,  32
# current lookahead:  ;
# lookahead index 5
# table entry:  r4
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D', '32']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24, 'i', 29]
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24, 'i']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24]
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17]
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8]
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'S']
# next lookahead:  S
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'S', '7']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'S', '7']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'S', '7']
# token index  9
# State,  7
# current lookahead:  ;
# lookahead index 5
# table entry:  s16
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'S', '7', ';', 16]
# token index  10
# State,  16
# current lookahead:  c
# lookahead index 6
# table entry:  r2
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'S', '7', ';', 16]
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'S', '7', ';']
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'S', '7']
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'S']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# token index  10
# State,  6
# current lookahead:  c
# lookahead index 6
# table entry:  s8
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8]
# token index  11
# State,  8
# current lookahead:  v
# lookahead index 7
# table entry:  s17
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17]
# token index  12
# State,  17
# current lookahead:  i
# lookahead index 2
# table entry:  s24
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24]
# token index  13
# State,  24
# current lookahead:  i
# lookahead index 2
# table entry:  s29
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29]
# token index  14
# State,  29
# current lookahead:  e
# lookahead index 16
# table entry:  s35
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'e', 35]
# token index  15
# State,  35
# current lookahead:  ;
# lookahead index 5
# table entry:  r13
# popping using reduction rule number:  13  rule:  D  ->  e  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'e', 35]
# popping using reduction rule number:  13  rule:  D  ->  e  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'e']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D']
# next lookahead:  D
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D', '32']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D', '32']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D', '32']
# token index  15
# State,  32
# current lookahead:  ;
# lookahead index 5
# table entry:  r4
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D', '32']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29]
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24]
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17]
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8]
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# next lookahead:  S
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# token index  15
# State,  15
# current lookahead:  ;
# lookahead index 5
# table entry:  s23
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# token index  16
# State,  23
# current lookahead:  m
# lookahead index 8
# table entry:  r3
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# token index  16
# State,  6
# current lookahead:  m
# lookahead index 8
# table entry:  s9
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9]
# token index  17
# State,  9
# current lookahead:  v
# lookahead index 7
# table entry:  s18
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18]
# token index  18
# State,  18
# current lookahead:  i
# lookahead index 2
# table entry:  s25
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25]
# token index  19
# State,  25
# current lookahead:  i
# lookahead index 2
# table entry:  s30
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30]
# token index  20
# State,  30
# current lookahead:  e
# lookahead index 16
# table entry:  s35
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'e', 35]
# token index  21
# State,  35
# current lookahead:  ;
# lookahead index 5
# table entry:  r13
# popping using reduction rule number:  13  rule:  D  ->  e  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'e', 35]
# popping using reduction rule number:  13  rule:  D  ->  e  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'e']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D']
# next lookahead:  D
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D', '37']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D', '37']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D', '37']
# token index  21
# State,  37
# current lookahead:  ;
# lookahead index 5
# table entry:  r5
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D', '37']
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D']
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30]
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i']
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25]
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i']
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18]
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v']
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9]
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# next lookahead:  S
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# token index  21
# State,  15
# current lookahead:  ;
# lookahead index 5
# table entry:  s23
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# token index  22
# State,  23
# current lookahead:  m
# lookahead index 8
# table entry:  r3
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# token index  22
# State,  6
# current lookahead:  m
# lookahead index 8
# table entry:  s9
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9]
# token index  23
# State,  9
# current lookahead:  v
# lookahead index 7
# table entry:  s18
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18]
# token index  24
# State,  18
# current lookahead:  i
# lookahead index 2
# table entry:  s25
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25]
# token index  25
# State,  25
# current lookahead:  i
# lookahead index 2
# table entry:  s30
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30]
# token index  26
# State,  30
# current lookahead:  n
# lookahead index 14
# table entry:  s33
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'n', 33]
# token index  27
# State,  33
# current lookahead:  ;
# lookahead index 5
# table entry:  r11
# popping using reduction rule number:  11  rule:  D  ->  n  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'n', 33]
# popping using reduction rule number:  11  rule:  D  ->  n  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'n']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D']
# next lookahead:  D
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D', '37']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D', '37']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D', '37']
# token index  27
# State,  37
# current lookahead:  ;
# lookahead index 5
# table entry:  r5
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D', '37']
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D']
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30]
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i']
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25]
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i']
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18]
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v']
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9]
# popping using reduction rule number:  5  rule:  S  ->  mviid  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# next lookahead:  S
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# token index  27
# State,  15
# current lookahead:  ;
# lookahead index 5
# table entry:  s23
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# token index  28
# State,  23
# current lookahead:  h
# lookahead index 9
# table entry:  r3
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# token index  28
# State,  6
# current lookahead:  h
# lookahead index 9
# table entry:  s10
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'h', 10]
# token index  29
# State,  10
# current lookahead:  i
# lookahead index 2
# table entry:  s19
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'h', 10, 'i', 19]
# token index  30
# State,  19
# current lookahead:  i
# lookahead index 2
# table entry:  s26
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'h', 10, 'i', 19, 'i', 26]
# token index  31
# State,  26
# current lookahead:  ;
# lookahead index 5
# table entry:  r6
# popping using reduction rule number:  6  rule:  S  ->  hii  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'h', 10, 'i', 19, 'i', 26]
# popping using reduction rule number:  6  rule:  S  ->  hii  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'h', 10, 'i', 19, 'i']
# popping using reduction rule number:  6  rule:  S  ->  hii  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'h', 10, 'i', 19]
# popping using reduction rule number:  6  rule:  S  ->  hii  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'h', 10, 'i']
# popping using reduction rule number:  6  rule:  S  ->  hii  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'h', 10]
# popping using reduction rule number:  6  rule:  S  ->  hii  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'h']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# next lookahead:  S
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# token index  31
# State,  15
# current lookahead:  ;
# lookahead index 5
# table entry:  s23
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# token index  32
# State,  23
# current lookahead:  r
# lookahead index 12
# table entry:  r3
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# token index  32
# State,  6
# current lookahead:  r
# lookahead index 12
# table entry:  s13
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13]
# token index  33
# State,  13
# current lookahead:  i
# lookahead index 2
# table entry:  s22
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22]
# token index  34
# State,  22
# current lookahead:  o
# lookahead index 10
# table entry:  s11
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'o', 11]
# token index  35
# State,  11
# current lookahead:  v
# lookahead index 7
# table entry:  s20
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'o', 11, 'v', 20]
# token index  36
# State,  20
# current lookahead:  ;
# lookahead index 5
# table entry:  r7
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'o', 11, 'v', 20]
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'o', 11, 'v']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'o', 11]
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'o']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S']
# next lookahead:  S
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7']
# token index  36
# State,  7
# current lookahead:  ;
# lookahead index 5
# table entry:  s16
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7', ';', 16]
# token index  37
# State,  16
# current lookahead:  o
# lookahead index 10
# table entry:  r2
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7', ';', 16]
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7', ';']
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7']
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# token index  37
# State,  28
# current lookahead:  o
# lookahead index 10
# table entry:  s11
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'o', 11]
# token index  38
# State,  11
# current lookahead:  v
# lookahead index 7
# table entry:  s20
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# token index  39
# State,  20
# current lookahead:  ;
# lookahead index 5
# table entry:  r7
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'o', 11]
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'o']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S']
# next lookahead:  S
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15']
# token index  39
# State,  15
# current lookahead:  ;
# lookahead index 5
# table entry:  s23
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# token index  40
# State,  23
# current lookahead:  d
# lookahead index 13
# table entry:  r3
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# token index  40
# State,  28
# current lookahead:  d
# lookahead index 13
# table entry:  s31
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'd', 31]
# token index  41
# State,  31
# current lookahead:  ;
# lookahead index 5
# table entry:  r10
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'd', 31]
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'd']
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L']
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22]
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i']
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13]
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# next lookahead:  S
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# token index  41
# State,  15
# current lookahead:  ;
# lookahead index 5
# table entry:  s23
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# token index  42
# State,  23
# current lookahead:  l
# lookahead index 11
# table entry:  r3
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# token index  42
# State,  6
# current lookahead:  l
# lookahead index 11
# table entry:  s12
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12]
# token index  43
# State,  12
# current lookahead:  v
# lookahead index 7
# table entry:  s21
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12, 'v', 21]
# token index  44
# State,  21
# current lookahead:  ;
# lookahead index 5
# table entry:  r9
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12, 'v', 21]
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12, 'v']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12]
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# next lookahead:  S
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# token index  44
# State,  15
# current lookahead:  ;
# lookahead index 5
# table entry:  s23
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# token index  45
# State,  23
# current lookahead:  l
# lookahead index 11
# table entry:  r3
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# token index  45
# State,  6
# current lookahead:  l
# lookahead index 11
# table entry:  s12
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12]
# token index  46
# State,  12
# current lookahead:  v
# lookahead index 7
# table entry:  s21
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12, 'v', 21]
# token index  47
# State,  21
# current lookahead:  ;
# lookahead index 5
# table entry:  r9
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12, 'v', 21]
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12, 'v']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12]
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# next lookahead:  S
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# token index  47
# State,  15
# current lookahead:  ;
# lookahead index 5
# table entry:  s23
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# token index  48
# State,  23
# current lookahead:  r
# lookahead index 12
# table entry:  r3
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# token index  48
# State,  6
# current lookahead:  r
# lookahead index 12
# table entry:  s13
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13]
# token index  49
# State,  13
# current lookahead:  i
# lookahead index 2
# table entry:  s22
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22]
# token index  50
# State,  22
# current lookahead:  o
# lookahead index 10
# table entry:  s11
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'o', 11]
# token index  51
# State,  11
# current lookahead:  v
# lookahead index 7
# table entry:  s20
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'o', 11, 'v', 20]
# token index  52
# State,  20
# current lookahead:  ;
# lookahead index 5
# table entry:  r7
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'o', 11, 'v', 20]
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'o', 11, 'v']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'o', 11]
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'o']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S']
# next lookahead:  S
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7']
# token index  52
# State,  7
# current lookahead:  ;
# lookahead index 5
# table entry:  s16
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7', ';', 16]
# token index  53
# State,  16
# current lookahead:  o
# lookahead index 10
# table entry:  r2
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7', ';', 16]
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7', ';']
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7']
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# token index  53
# State,  28
# current lookahead:  o
# lookahead index 10
# table entry:  s11
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'o', 11]
# token index  54
# State,  11
# current lookahead:  v
# lookahead index 7
# table entry:  s20
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# token index  55
# State,  20
# current lookahead:  ;
# lookahead index 5
# table entry:  r7
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'o', 11]
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'o']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S']
# next lookahead:  S
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15']
# token index  55
# State,  15
# current lookahead:  ;
# lookahead index 5
# table entry:  s23
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# token index  56
# State,  23
# current lookahead:  d
# lookahead index 13
# table entry:  r3
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28']
# token index  56
# State,  28
# current lookahead:  d
# lookahead index 13
# table entry:  s31
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'd', 31]
# token index  57
# State,  31
# current lookahead:  ;
# lookahead index 5
# table entry:  r10
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'd', 31]
# ...
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# token index  82
# State,  6
# current lookahead:  o
# lookahead index 10
# table entry:  s11
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11]
# token index  83
# State,  11
# current lookahead:  v
# lookahead index 7
# table entry:  s20
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20]
# token index  84
# State,  20
# current lookahead:  i
# lookahead index 2
# table entry:  s27
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20, 'i', 27]
# token index  85
# State,  27
# current lookahead:  ;
# lookahead index 5
# table entry:  r8
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20, 'i', 27]
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20, 'i']
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20]
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v']
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11]
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# next lookahead:  S
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# token index  85
# State,  15
# current lookahead:  ;
# lookahead index 5
# table entry:  s23
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# token index  86
# State,  23
# current lookahead:  l
# lookahead index 11
# table entry:  r3
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# token index  86
# State,  6
# current lookahead:  l
# lookahead index 11
# table entry:  s12
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12]
# token index  87
# State,  12
# current lookahead:  v
# lookahead index 7
# table entry:  s21
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12, 'v', 21]
# token index  88
# State,  21
# current lookahead:  ;
# lookahead index 5
# table entry:  r9
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12, 'v', 21]
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12, 'v']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12]
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# next lookahead:  S
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# token index  88
# State,  15
# current lookahead:  ;
# lookahead index 5
# table entry:  s23
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# token index  89
# State,  23
# current lookahead:  o
# lookahead index 10
# table entry:  r3
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# token index  89
# State,  6
# current lookahead:  o
# lookahead index 10
# table entry:  s11
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11]
# token index  90
# State,  11
# current lookahead:  v
# lookahead index 7
# table entry:  s20
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20]
# token index  91
# State,  20
# current lookahead:  i
# lookahead index 2
# table entry:  s27
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20, 'i', 27]
# token index  92
# State,  27
# current lookahead:  ;
# lookahead index 5
# table entry:  r8
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20, 'i', 27]
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20, 'i']
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20]
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v']
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11]
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# next lookahead:  S
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# token index  92
# State,  15
# current lookahead:  ;
# lookahead index 5
# table entry:  s23
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# token index  93
# State,  23
# current lookahead:  t
# lookahead index 4
# table entry:  r3
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# stack after popping:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5]
# stack after appending LHS var:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# next lookahead:  L
# stack after appending entry after that lookahead:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# final state of stack after reduction and pushing variable and new state:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# token index  93
# State,  6
# current lookahead:  t
# lookahead index 4
# table entry:  s14
# stack:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 't', 14]
# token index  94
# State,  14
# current lookahead:  $
# lookahead index 18
# table entry:  r1
# popping using reduction rule number:  1  rule:  P  ->  ziibLt  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 't', 14]
# popping using reduction rule number:  1  rule:  P  ->  ziibLt  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 't']
# popping using reduction rule number:  1  rule:  P  ->  ziibLt  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6']
# popping using reduction rule number:  1  rule:  P  ->  ziibLt  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L']
# popping using reduction rule number:  1  rule:  P  ->  ziibLt  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5]
# popping using reduction rule number:  1  rule:  P  ->  ziibLt  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b']
# popping using reduction rule number:  1  rule:  P  ->  ziibLt  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4]
# popping using reduction rule number:  1  rule:  P  ->  ziibLt  Stack contents:  [0, 'z', 2, 'i', 3, 'i']
# popping using reduction rule number:  1  rule:  P  ->  ziibLt  Stack contents:  [0, 'z', 2, 'i', 3]
# popping using reduction rule number:  1  rule:  P  ->  ziibLt  Stack contents:  [0, 'z', 2, 'i']
# popping using reduction rule number:  1  rule:  P  ->  ziibLt  Stack contents:  [0, 'z', 2]
# popping using reduction rule number:  1  rule:  P  ->  ziibLt  Stack contents:  [0, 'z']
# stack after popping:  [0]
# stack after appending LHS var:  [0, 'P']
# next lookahead:  P
# stack after appending entry after that lookahead:  [0, 'P', '1']
# final state of stack after reduction and pushing variable and new state:  [0, 'P', '1']
# stack:  [0, 'P', '1']
# token index  94
# State,  1
# current lookahead:  $
# lookahead index 18
# table entry:  acc
# lookahead is $, stack contents =  [0, 'P', '1']  and entry is  acc  so, accept
# *** VALID PROGRAM ***: program-string can be derived using the grammar
# with rulestack:  [[14, 'D', 'w'], [4, 'S', 'cviiD'], [2, 'L', 'S;'], [13, 'D', 'e'], [4, 'S', 'cviiD'], [3, 'L', 'LS;'], [13, 'D', 'e'], [5, 'S', 'mviid'], [3, 'L', 'LS;'], [11, 'D', 'n'], [5, 'S', 'mviid'], [3, 'L', 'LS;'], [6, 'S', 'hii'], [3, 'L', 'LS;'], [7, 'S', 'ov'], [2, 'L', 'S;'], [7, 'S', 'ov'], [3, 'L', 'LS;'], [10, 'S', 'riLd'], [3, 'L', 'LS;'], [9, 'S', 'lv'], [3, 'L', 'LS;'], [9, 'S', 'lv'], [3, 'L', 'LS;'], [7, 'S', 'ov'], [2, 'L', 'S;'], [7, 'S', 'ov'], [3, 'L', 'LS;'], [10, 'S', 'riLd'], [3, 'L', 'LS;'], [9, 'S', 'lv'], [2, 'L', 'S;'], [10, 'S', 'riLd'], [3, 'L', 'LS;'], [8, 'S', 'ovi'], [3, 'L', 'LS;'], [9, 'S', 'lv'], [3, 'L', 'LS;'], [9, 'S', 'lv'], [3, 'L', 'LS;'], [8, 'S', 'ovi'], [3, 'L', 'LS;'], [9, 'S', 'lv'], [3, 'L', 'LS;'], [8, 'S', 'ovi'], [3, 'L', 'LS;'], [9, 'S', 'lv'], [3, 'L', 'LS;'], [8, 'S', 'ovi'], [3, 'L', 'LS;'], [1, 'P', 'ziibLt']]
# Rule number, rule in right order:  1 ('P', 'ziibLt')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  8 ('S', 'ovi')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  9 ('S', 'lv')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  8 ('S', 'ovi')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  9 ('S', 'lv')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  8 ('S', 'ovi')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  9 ('S', 'lv')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  9 ('S', 'lv')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  8 ('S', 'ovi')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  10 ('S', 'riLd')
#
# Rule number, rule in right order:  2 ('L', 'S;')
#
# Rule number, rule in right order:  9 ('S', 'lv')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  10 ('S', 'riLd')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  7 ('S', 'ov')
#
# Rule number, rule in right order:  2 ('L', 'S;')
#
# Rule number, rule in right order:  7 ('S', 'ov')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  9 ('S', 'lv')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  9 ('S', 'lv')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  10 ('S', 'riLd')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  7 ('S', 'ov')
#
# Rule number, rule in right order:  2 ('L', 'S;')
#
# Rule number, rule in right order:  7 ('S', 'ov')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  6 ('S', 'hii')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  5 ('S', 'mviid')
#
# Rule number, rule in right order:  11 ('D', 'n')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  5 ('S', 'mviid')
#
# Rule number, rule in right order:  13 ('D', 'e')
#
# Rule number, rule in right order:  3 ('L', 'LS;')
#
# Rule number, rule in right order:  4 ('S', 'cviiD')
#
# Rule number, rule in right order:  13 ('D', 'e')
#
# Rule number, rule in right order:  2 ('L', 'S;')
#
# Rule number, rule in right order:  4 ('S', 'cviiD')
#
# Rule number, rule in right order:  14 ('D', 'w')

# %% [markdown]
# ### Thank you!
