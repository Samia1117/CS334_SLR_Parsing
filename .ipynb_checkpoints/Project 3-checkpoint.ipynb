# %% [markdown]
# ### Welcome to Project 3: Building an interpreter and visualizations for a Cat and Mouse program

# %%
# filename later gets updated to the .mc filename input by user

filepath = ""
extension = ".txt"
filename = "parsedata" + extension            ## FIRST RUN

# %%
def makeTable(filename, LRtable):
    # Open parsedata.txt and do some file processing
    # This file is same for every .mc file to be processed, so it is done just once at the beginning
    file = open(filename, "r")
    idx = 0
    for line in file:
        lookaheads = line.split('&')
        LRtable.append(lookaheads)   # keep \n for now
        if idx == 38:
            break
        idx +=1
    idx = 0
    for line in file:
        lookaheads = line.split('&')[1:]         # get rid of the extra numbered row for variables
        LRtable[idx] = LRtable[idx] + lookaheads  # we'll concatenate it with the row of terminals already numbered
        idx +=1
        
    n = LRtable[0].index('$\n')
    for i in range(len(LRtable)):
        withNln =  LRtable[i][-1]
        LRtable[i][-1] = withNln[0:-1]
        withNln2 =  LRtable[i][n]
        LRtable[i][n] = withNln2[0:-1]
    return LRtable
    #print(LRtable)

# %%
table = []
LRtable = makeTable(filename, table)  ### FIRST RUN
LRtable2 = LRtable.copy()

# print(len(LRtable[0]))
# print(len(LRtable[1]))

# %%
# a nice visualization of the table
from tabulate import tabulate
print(tabulate(LRtable))
# Out:
# --  --  ---  --  ---  ---  --  ---  --  ---  ---  ---  ---  ---  ---  ---  ---  ---  ---  -  --  --  --
#     z   i    b   t    ;    c   v    m   h    o    l    r    d    n    s    e    w    $    P  L   S   D
# 0   s2                                                                                    1
# 1                                                                                    acc
# 2       s3
# 3       s4
# 4            s5
# 5                          s8       s9  s10  s11  s12  s13                                   6   7
# 6                s14       s8       s9  s10  s11  s12  s13                                       15
# 7                     s16
# 8                              s17
# 9                              s18
# 10      s19
# 11                             s20
# 12                             s21
# 13      s22
# 14                                                                                   r1
# 15                    s23
# 16               r2        r2       r2  r2   r2   r2   r2   r2
# 17      s24
# 18      s25
# 19      s26
# 20      s27           r7
# 21                    r9
# 22                         s8       s9  s10  s11  s12  s13                                   28  7
# 23               r3        r3       r3  r3   r3   r3   r3   r3
# 24      s29
# 25      s30
# 26                    r6
# 27                    r8
# 28                         s8       s9  s10  s11  s12  s13  s31                                  15
# 29                                                               s33  s34  s35  s36                  32
# 30                                                               s33  s34  s35  s36                  37
# 31                    r10
# 32                    r4
# 33                    r11
# 34                    r12
# 35                    r13
# 36                    r14
# 37                    r5
# --  --  ---  --  ---  ---  --  ---  --  ---  ---  ---  ---  ---  ---  ---  ---  ---  ---  -  --  --  --

# %%
# functions from project 1 - works as described there

def valid_int(word, digits):
    try:
        int(word)
    except ValueError:
        return False
    else:
        if word.startswith("0"):
            if len(word) >1:
                return False
        if len(word)>3:
            return False
        return True
    
def valid_variable(word, digits, letters):
    word = list(word)
    digits_in_word = set(word).intersection(set(digits))
    letters_in_word = set(word).intersection(set(letters))
    if (digits_in_word.union(letters_in_word) != set(word)):
        return False                  # foreign symbol outside letters and digits
    if (digits_in_word == set(word)):
        if len(word)<4:        # all digits but length less than 4
            return False
    return True     

def get_token_type(word, digits, letters, keywords, 
              punctuations):
    if ((word in keywords) or (word in punctuations)):
        return (word, "NULL")
    if valid_int(word, digits):
        return ("integer", word)
    if valid_variable(word, digits, letters):
        return ("variable", '0')
    else:
        return ("error", '0')

def comment_starts(wordsList):
    return wordsList.index('//')

def has_comment(wordsList):
    if '//' in wordsList:
        return True
    return False

# %%
# Just a simple initialization of the variables we will deal with

def create_symtable(word, token_type, value, symtable):
    if (value == "NULL"):
        return
    if token_type == "integer":
        return
    variables_found = [symtable[k][1] for k in range(len(symtable)) if symtable[k][0] == "variable"]
    if token_type == "variable":
        if (word in variables_found):
            return   # no need to deal with this variable again
        else:
            symtable.append(["variable", word, [0, 0], 1])  # ["TYPE","CH VALUE", "POSITION", "ORIENTATION"]
            # 1 = north, 2 = east, 3 = south, 4 = west
        
    return

# %%
def scanner(filename, symtable):  
    tuplist = []
    file = open(filename, "r")
    line_index = 0
    for line in file:
        if ('//' in line):
            idx = line.index('//')
            line = line[0:idx]
        words_in_line = line.strip().split(" ")
        if words_in_line == []:
            continue
        while(words_in_line[0] == '' or words_in_line[0] == '\t'):
            words_in_line = words_in_line[1:]
            if(len(words_in_line)) ==0:
                break
        if words_in_line == []:
            continue
        while(words_in_line[-1] == '' or words_in_line[-1] == '\t'):
            n = len(words_in_line)
            words_in_line = words_in_line[0:n]
        line_index +=1
        for word in words_in_line:
            if word == "":
                continue
            word = word.lower()
            (token_type, value) = get_token_type(word, digits, letters, keywords, punctuations)
            if token_type == "error":
                print("error on line: ", line_index, "on word: ", word, " with value: ", value)
                print(words_in_line)
                return
            else:
                if token_type == "intger":
                    word = int(word)
                tuplist.append((token_type, word)) # a list of the vaild tokens and their characters one by one
                create_symtable(word, token_type, value, symtable) # Throw this information away for now
    return tuplist

# %%
def refine_strList(strList, specials, shorthands):
    inputStr = ''
    for item in strList:
        if item not in specials:
            inputStr += item[0]
        else:
            i = specials.index(item)
            inputStr += shorthands[i]
    return inputStr

# %%
# Has 5 fields -- maximum number of variables or terminals on the RHS of a production rule
# node.name is the first attribute and identifies the type of node
# Typically, 5th attribute (node.four) has a reference to another node
class Node(object):
    def __init__(self, name = "null", one = "null", two = "null", three = "null", four = "null"):
        self._name = name
        self._one = one
        self._two = two
        self._three = three
        self._four = four
        
    @property
    def name(self):
        return self._name
    @property
    def one(self):
        return self._one
    @property
    def two(self):
        return self._two
    @property
    def three(self):
        return self._three
    @property
    def four(self):
        return self._four
    
    @name.setter
    def name(self, value):
        self._name = value
    @one.setter
    def one(self, value):
        self._one = value
    @two.setter
    def two(self, value):
        self._two = value
    @three.setter
    def three(self, value):
        self._three = value
    @four.setter
    def four(self, value):
        self._four = value

# %%
''' Return: a node object
    Parameters: two empty nodes objects: LHS and RHS, and a list of 'attributes' that are added to RHS node, and 
    then a reference from LHS is made to RHS through its fourth field
'''
def buildNode(LHS, RHS, attributes):      # RHS node is to be popped off the stack
    if ';' in attributes:
        attributes.remove(';')
    n = len(attributes)
    if n>5:
        print("6 attribute node found: ", attributes)
    for i in range(n):
        attribute = attributes[i]        # First build the RHS node, then set it as the rightmost field of LHS node 
        if i==0:
            RHS.name = attribute
        elif i==1:
            RHS.one = attribute
        elif i ==2:
            RHS.two = attribute
        elif i ==3:
            RHS.three = attribute
        elif i ==4:
            RHS.four = attribute
        #node.add_attribute(i, attribute)
        if (i== (n-1)):
            print("My fields are the following: ")
            print(RHS.name)
            print(RHS.one)
            print(RHS.two)
            print(RHS.three)
            print(RHS.four)
    if (RHS.name in ["cat", "mouse", "hole", "move", "clockwise", "repeat"]):
        LHS.name = "statement"
    elif (RHS.name in ["north", "east", "south", "west"]):
        LHS.name = RHS.name
    elif (RHS.name == "size"):
        LHS.name = "program"
    elif (RHS.name in ["sequenceNode", "statement"]):
        LHS.name = "sequenceNode"
    elif type(RHS.name) is Node:
        LHS.name = "sequenceNode"
    LHS.four = RHS
    return LHS

# %%
'''Return: None
    Parameters: 2 stacks: the ststack building nested nodes, the 'vis_stack' to help visualize node building
    Updates the ststack to build program node, "semi bottom-up"
'''
def updateSTstack(ststack, vis_stack, org_vals, RHSnode, rule_num, ruleToVar):
    print("Original values: ", org_vals)
    if ("".join(RHSnode) == ruleToVar[rule_num][1]):
        #LHS = ruleToVar[rule_num][0]
        LHSnode = Node()
        RHSnode = Node()
        LHSnode = buildNode(LHSnode, RHSnode, org_vals)
        print("Found rule to RHS variable correspondence! Can use it to decide type of Node")
        vis_stack.append(ruleToVar[rule_num][0])
        ststack.append(LHSnode)
        print("LHS node is of type: ", LHSnode.name)
    print("STstack: ", ststack)
    print("vis stack: ", vis_stack)
    return

# %%
# More global variables

LRtable = LRtable2[1:]
lookaheads = LRtable2[0]
#print(lookaheads)

ruleToVar = [('P*','P'), ('P', 'ziibLt'), ('L', 'S;'), ('L', 'LS;'), ('S', 'cviiD'), 
             ('S', 'mviiD'), ('S', 'hii'), ('S', 'ov'), ('S', 'ovi'), ('S', 'lv'), ('S', 'riLd'),
             ('D', 'n'), ('D', 's'), ('D', 'e'), ('D', 'w')]
rulestack = []

# %%
def handleNextEntry(state, inputStr, tokenidx, stack, rulestack, ststack, vis_stack, wordList):
    lookahead = '$'
    org_word = ""
    if tokenidx<len(inputStr):
        lookahead = inputStr[tokenidx]
        org_word = wordList[tokenidx]
    lookahead_index = lookaheads.index(lookahead)
    entry = LRtable[state][lookahead_index]
    if entry == '':
        print("blank entry on this lookahead = ", lookahead, " with state = ",state, " breaking")
        print("##INVALID program##")
        return
    if entry.startswith('s'):
        stack.append(lookahead)
        ststack.append(org_word)
        vis_stack.append(org_word)
        
        next_state = int(entry[1:])
        stack.append(next_state)
        handleNextEntry(next_state, inputStr, tokenidx+1, stack, rulestack, ststack, vis_stack, wordList)
    elif entry.startswith('r'):
        rule_num = int(entry[1:])
        RHSvar = ruleToVar[rule_num][1]
        LHSvar = ruleToVar[rule_num][0]
        rulestack.append([rule_num, LHSvar, RHSvar])
        print("popping using reduction rule number: ", rule_num, " rule: ", LHSvar, " -> ", RHSvar, " Stack contents: ", stack)
        RHSnode = []
        org_vals = []
        for i in range(2*len(RHSvar)):
            if(i%2!=0):
                val = stack.pop()
                RHSnode.insert(0, val)
                continue
            org_val = ststack.pop()
            vis_stack.pop()
            org_vals.insert(0, org_val)
            stack.pop()
        updateSTstack(ststack, vis_stack, org_vals, RHSnode, rule_num, ruleToVar)
        next_state = int(stack[-1])            # before I push the LHS variable, mark which state I was last in
        stack.append(LHSvar)
        lookahead = stack[-1]
        lookahead_index = lookaheads.index(lookahead)
        entry = LRtable[next_state][lookahead_index] 
        stack.append(entry)   
        next_state = int(stack[-1])
        #print("final state of stack after reduction and pushing variable and new state: ", stack)
        handleNextEntry(next_state, inputStr, tokenidx, stack, rulestack, ststack, vis_stack, wordList)
    elif entry == 'acc':
        print("lookahead is $, stack contents = ", stack, " and entry is ", entry, " so, accept")
        print ("*** VALID PROGRAM ***: program-string can be derived using the grammar")
        #print("with rulestack: " , rulestack)
        # print("with original stack: " , org_stack)
        return ststack
    else:
        print("Encountered blank entry with stack = ", stack, "lookahead ", lookahead, "entry: ", entry )
        print ("*** INVALID PROGRAM ***: not syntactically correct")
    return

# %%
## Set up input files and global parameters -- my files are in a folder called 'dataproj2'. Change to "" if in same folder

filepath = "dataproj2/"
#filepath = input("Please enter a filepath + "/", (empty string if same directory as this file): ")

keywords = ["begin", "halt","cat", "mouse", "clockwise", "move", "north", "south", "east", "west", "hole", 
          "repeat", "size", "end"]
punctuations = [";"]               
letters = list("abcdefghijklmnopqrstuvwxyz")
digits = list("0123456789")
specials = ['size', 'move', 'clockwise', 'end', 'halt']
shorthands = ['z', 'o', 'l', 'd', 't']

filename = input("Please enter a filename, (e.g. sample1.mc/ sample2.mc): ")
filename2 = filepath + filename
# Out:
# Please enter a filename, (e.g. sample1.mc/ sample2.mc): sample4.mc

# %%
# Same as in project 2
def parser(filename, rulestack, ststack, vis_stack, symtable):
    tuplist = scanner(filename, symtable)
    inputStr = ''
    wordList = []
    if tuplist != []:     
        strList = [tuplist[k][0] for k in range(len(tuplist))] # tupilist[1] is the word in line encountered
        wordList = [tuplist[k][1] for k in range(len(tuplist))]
        inputStr = refine_strList(strList, specials, shorthands)
    else:
        print("INVALID program: has invalid tokens")
    print(inputStr)
    stack = []
    state = 0
    stack.append(state)
    tokenidx = 0
    ststack = handleNextEntry(state, inputStr, tokenidx, stack, rulestack, ststack, vis_stack, wordList)
    return wordList

# %%
ststack = []   #st stack will have 1 item at the end: a "program node" with references to all program statements
symtable = []
vis_stack = []
wordList = parser(filename2, rulestack, ststack, vis_stack, symtable)    ## SECOND RUN
# Out:
# ziibcviiw;cviin;cviie;cviis;hii;mviie;mviie;mviiw;mviiw;ririov;ov;ov;ov;ov;ov;ov;ov;lv;lv;lv;lv;ov;ov;ov;ov;ov;ov;ov;ov;rilv;lv;lv;lv;d;d;lv;lv;lv;lv;d;t
# popping using reduction rule number:  14  rule:  D  ->  w  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'w', 36]
# Original values:  ['west']
# My fields are the following:
# west
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  west
# STstack:  ['size', '25', '25', 'begin', 'cat', 'c1', '15', '15', <__main__.Node object at 0x0000025C72744588>]
# vis stack:  ['size', '25', '25', 'begin', 'cat', 'c1', '15', '15', 'D']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D', '32']
# Original values:  ['cat', 'c1', '15', '15', <__main__.Node object at 0x0000025C72744588>]
# My fields are the following:
# cat
# c1
# 15
# 15
# <__main__.Node object at 0x0000025C72744588>
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C726EA6C8>]
# vis stack:  ['size', '25', '25', 'begin', 'S']
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'S', '7', ';', 16]
# Original values:  [<__main__.Node object at 0x0000025C726EA6C8>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C726EA6C8>
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C726EA748>]
# vis stack:  ['size', '25', '25', 'begin', 'L']
# popping using reduction rule number:  11  rule:  D  ->  n  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'n', 33]
# Original values:  ['north']
# My fields are the following:
# north
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  north
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C726EA748>, 'cat', 'c2', '11', '15', <__main__.Node object at 0x0000025C726EAF08>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'cat', 'c2', '11', '15', 'D']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D', '32']
# Original values:  ['cat', 'c2', '11', '15', <__main__.Node object at 0x0000025C726EAF08>]
# My fields are the following:
# cat
# c2
# 11
# 15
# <__main__.Node object at 0x0000025C726EAF08>
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C726EA748>, <__main__.Node object at 0x0000025C726CCB08>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C726EA748>, <__main__.Node object at 0x0000025C726CCB08>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C726EA748>
# <__main__.Node object at 0x0000025C726CCB08>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C7266C308>]
# vis stack:  ['size', '25', '25', 'begin', 'L']
# popping using reduction rule number:  13  rule:  D  ->  e  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'e', 35]
# Original values:  ['east']
# My fields are the following:
# east
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  east
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C7266C308>, 'cat', 'c3', '11', '11', <__main__.Node object at 0x0000025C7266C2C8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'cat', 'c3', '11', '11', 'D']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D', '32']
# Original values:  ['cat', 'c3', '11', '11', <__main__.Node object at 0x0000025C7266C2C8>]
# My fields are the following:
# cat
# c3
# 11
# 11
# <__main__.Node object at 0x0000025C7266C2C8>
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C7266C308>, <__main__.Node object at 0x0000025C7266C888>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C7266C308>, <__main__.Node object at 0x0000025C7266C888>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C7266C308>
# <__main__.Node object at 0x0000025C7266C888>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C7266CF08>]
# vis stack:  ['size', '25', '25', 'begin', 'L']
# popping using reduction rule number:  12  rule:  D  ->  s  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 's', 34]
# Original values:  ['south']
# My fields are the following:
# south
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  south
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C7266CF08>, 'cat', 'c4', '15', '11', <__main__.Node object at 0x0000025C7266CAC8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'cat', 'c4', '15', '11', 'D']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D', '32']
# Original values:  ['cat', 'c4', '15', '11', <__main__.Node object at 0x0000025C7266CAC8>]
# My fields are the following:
# cat
# c4
# 15
# 11
# <__main__.Node object at 0x0000025C7266CAC8>
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C7266CF08>, <__main__.Node object at 0x0000025C7252ECC8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C7266CF08>, <__main__.Node object at 0x0000025C7252ECC8>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C7266CF08>
# <__main__.Node object at 0x0000025C7252ECC8>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C7252E148>]
# vis stack:  ['size', '25', '25', 'begin', 'L']
# popping using reduction rule number:  6  rule:  S  ->  hii  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'h', 10, 'i', 19, 'i', 26]
# Original values:  ['hole', '13', '13']
# My fields are the following:
# hole
# 13
# 13
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C7252E148>, <__main__.Node object at 0x0000025C725B2608>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C7252E148>, <__main__.Node object at 0x0000025C725B2608>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C7252E148>
# <__main__.Node object at 0x0000025C725B2608>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C725B2BC8>]
# vis stack:  ['size', '25', '25', 'begin', 'L']
# popping using reduction rule number:  13  rule:  D  ->  e  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'e', 35]
# Original values:  ['east']
# My fields are the following:
# east
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  east
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C725B2BC8>, 'mouse', 'tim', '2', '2', <__main__.Node object at 0x0000025C725B2B08>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'mouse', 'tim', '2', '2', 'D']
# popping using reduction rule number:  5  rule:  S  ->  mviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D', '37']
# Original values:  ['mouse', 'tim', '2', '2', <__main__.Node object at 0x0000025C725B2B08>]
# My fields are the following:
# mouse
# tim
# 2
# 2
# <__main__.Node object at 0x0000025C725B2B08>
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C725B2BC8>, <__main__.Node object at 0x0000025C725B2D08>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C725B2BC8>, <__main__.Node object at 0x0000025C725B2D08>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C725B2BC8>
# <__main__.Node object at 0x0000025C725B2D08>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C726FD948>]
# vis stack:  ['size', '25', '25', 'begin', 'L']
# popping using reduction rule number:  13  rule:  D  ->  e  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'e', 35]
# Original values:  ['east']
# My fields are the following:
# east
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  east
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C726FD948>, 'mouse', 'tony', '4', '4', <__main__.Node object at 0x0000025C726FDDC8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'mouse', 'tony', '4', '4', 'D']
# popping using reduction rule number:  5  rule:  S  ->  mviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D', '37']
# Original values:  ['mouse', 'tony', '4', '4', <__main__.Node object at 0x0000025C726FDDC8>]
# My fields are the following:
# mouse
# tony
# 4
# 4
# <__main__.Node object at 0x0000025C726FDDC8>
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C726FD948>, <__main__.Node object at 0x0000025C726FDC08>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C726FD948>, <__main__.Node object at 0x0000025C726FDC08>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C726FD948>
# <__main__.Node object at 0x0000025C726FDC08>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C726FDB08>]
# vis stack:  ['size', '25', '25', 'begin', 'L']
# popping using reduction rule number:  14  rule:  D  ->  w  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'w', 36]
# Original values:  ['west']
# My fields are the following:
# west
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  west
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C726FDB08>, 'mouse', 'ron', '23', '23', <__main__.Node object at 0x0000025C726FDD08>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'mouse', 'ron', '23', '23', 'D']
# popping using reduction rule number:  5  rule:  S  ->  mviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D', '37']
# Original values:  ['mouse', 'ron', '23', '23', <__main__.Node object at 0x0000025C726FDD08>]
# My fields are the following:
# mouse
# ron
# 23
# 23
# <__main__.Node object at 0x0000025C726FDD08>
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C726FDB08>, <__main__.Node object at 0x0000025C722B8188>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C726FDB08>, <__main__.Node object at 0x0000025C722B8188>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C726FDB08>
# <__main__.Node object at 0x0000025C722B8188>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72635948>]
# vis stack:  ['size', '25', '25', 'begin', 'L']
# popping using reduction rule number:  14  rule:  D  ->  w  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'w', 36]
# Original values:  ['west']
# My fields are the following:
# west
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  west
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72635948>, 'mouse', 'mark', '17', '17', <__main__.Node object at 0x0000025C72731688>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'mouse', 'mark', '17', '17', 'D']
# popping using reduction rule number:  5  rule:  S  ->  mviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D', '37']
# Original values:  ['mouse', 'mark', '17', '17', <__main__.Node object at 0x0000025C72731688>]
# My fields are the following:
# mouse
# mark
# 17
# 17
# <__main__.Node object at 0x0000025C72731688>
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72635948>, <__main__.Node object at 0x0000025C72731288>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C72635948>, <__main__.Node object at 0x0000025C72731288>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C72635948>
# <__main__.Node object at 0x0000025C72731288>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>]
# vis stack:  ['size', '25', '25', 'begin', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'o', 11, 'v', 20]
# Original values:  ['move', 'c1']
# My fields are the following:
# move
# c1
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C727311C8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'S']
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'S', '7', ';', 16]
# Original values:  [<__main__.Node object at 0x0000025C727311C8>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C727311C8>
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72731F08>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'c2']
# My fields are the following:
# move
# c2
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72731F08>, <__main__.Node object at 0x0000025C726DF5C8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C72731F08>, <__main__.Node object at 0x0000025C726DF5C8>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C72731F08>
# <__main__.Node object at 0x0000025C726DF5C8>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7254C248>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'c3']
# My fields are the following:
# move
# c3
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7254C248>, <__main__.Node object at 0x0000025C726FAB08>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C7254C248>, <__main__.Node object at 0x0000025C726FAB08>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C7254C248>
# <__main__.Node object at 0x0000025C726FAB08>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C726F67C8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'c4']
# My fields are the following:
# move
# c4
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C726F67C8>, <__main__.Node object at 0x0000025C726F6F88>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C726F67C8>, <__main__.Node object at 0x0000025C726F6F88>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C726F67C8>
# <__main__.Node object at 0x0000025C726F6F88>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72656548>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'tim']
# My fields are the following:
# move
# tim
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72656548>, <__main__.Node object at 0x0000025C726A8088>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C72656548>, <__main__.Node object at 0x0000025C726A8088>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C72656548>
# <__main__.Node object at 0x0000025C726A8088>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7058BA48>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'tony']
# My fields are the following:
# move
# tony
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7058BA48>, <__main__.Node object at 0x0000025C70605E08>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C7058BA48>, <__main__.Node object at 0x0000025C70605E08>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C7058BA48>
# <__main__.Node object at 0x0000025C70605E08>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C726F1A48>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'ron']
# My fields are the following:
# move
# ron
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C726F1A48>, <__main__.Node object at 0x0000025C705C0608>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C726F1A48>, <__main__.Node object at 0x0000025C705C0608>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C726F1A48>
# <__main__.Node object at 0x0000025C705C0608>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C726AD608>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'mark']
# My fields are the following:
# move
# mark
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C726AD608>, <__main__.Node object at 0x0000025C726AD8C8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C726AD608>, <__main__.Node object at 0x0000025C726AD8C8>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C726AD608>
# <__main__.Node object at 0x0000025C726AD8C8>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72684308>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'tim']
# My fields are the following:
# clockwise
# tim
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72684308>, <__main__.Node object at 0x0000025C72721CC8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C72684308>, <__main__.Node object at 0x0000025C72721CC8>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C72684308>
# <__main__.Node object at 0x0000025C72721CC8>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C727219C8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'tony']
# My fields are the following:
# clockwise
# tony
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C727219C8>, <__main__.Node object at 0x0000025C72721048>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C727219C8>, <__main__.Node object at 0x0000025C72721048>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C727219C8>
# <__main__.Node object at 0x0000025C72721048>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72721208>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'ron']
# My fields are the following:
# clockwise
# ron
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72721208>, <__main__.Node object at 0x0000025C72724648>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C72721208>, <__main__.Node object at 0x0000025C72724648>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C72721208>
# <__main__.Node object at 0x0000025C72724648>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72724908>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'mark']
# My fields are the following:
# clockwise
# mark
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72724908>, <__main__.Node object at 0x0000025C72724B08>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C72724908>, <__main__.Node object at 0x0000025C72724B08>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C72724908>
# <__main__.Node object at 0x0000025C72724B08>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C70625308>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'c1']
# My fields are the following:
# move
# c1
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C70625308>, <__main__.Node object at 0x0000025C70625988>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C70625308>, <__main__.Node object at 0x0000025C70625988>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C70625308>
# <__main__.Node object at 0x0000025C70625988>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C727440C8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'c2']
# My fields are the following:
# move
# c2
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C727440C8>, <__main__.Node object at 0x0000025C70636508>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C727440C8>, <__main__.Node object at 0x0000025C70636508>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C727440C8>
# <__main__.Node object at 0x0000025C70636508>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72630C48>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'c3']
# My fields are the following:
# move
# c3
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72630C48>, <__main__.Node object at 0x0000025C7268C0C8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C72630C48>, <__main__.Node object at 0x0000025C7268C0C8>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C72630C48>
# <__main__.Node object at 0x0000025C7268C0C8>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7061CE88>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'c4']
# My fields are the following:
# move
# c4
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7061CE88>, <__main__.Node object at 0x0000025C7061C148>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C7061CE88>, <__main__.Node object at 0x0000025C7061C148>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C7061CE88>
# <__main__.Node object at 0x0000025C7061C148>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C70569808>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'tim']
# My fields are the following:
# move
# tim
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C70569808>, <__main__.Node object at 0x0000025C7251BF48>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C70569808>, <__main__.Node object at 0x0000025C7251BF48>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C70569808>
# <__main__.Node object at 0x0000025C7251BF48>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C726513C8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'tony']
# My fields are the following:
# move
# tony
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C726513C8>, <__main__.Node object at 0x0000025C72651208>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C726513C8>, <__main__.Node object at 0x0000025C72651208>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C726513C8>
# <__main__.Node object at 0x0000025C72651208>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72651B48>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'ron']
# My fields are the following:
# move
# ron
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72651B48>, <__main__.Node object at 0x0000025C72659148>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C72651B48>, <__main__.Node object at 0x0000025C72659148>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C72651B48>
# <__main__.Node object at 0x0000025C72659148>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72715DC8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'mark']
# My fields are the following:
# move
# mark
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C72715DC8>, <__main__.Node object at 0x0000025C726EA488>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C72715DC8>, <__main__.Node object at 0x0000025C726EA488>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C72715DC8>
# <__main__.Node object at 0x0000025C726EA488>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7266CD08>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'r', 13, 'i', 22, 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'tim']
# My fields are the following:
# clockwise
# tim
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7266CD08>, 'repeat', '3', <__main__.Node object at 0x0000025C725B2808>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'repeat', '3', 'S']
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'r', 13, 'i', 22, 'S', '7', ';', 16]
# Original values:  [<__main__.Node object at 0x0000025C725B2808>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C725B2808>
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7266CD08>, 'repeat', '3', <__main__.Node object at 0x0000025C726FD288>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'repeat', '3', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'r', 13, 'i', 22, 'L', '28', 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'tony']
# My fields are the following:
# clockwise
# tony
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7266CD08>, 'repeat', '3', <__main__.Node object at 0x0000025C726FD288>, <__main__.Node object at 0x0000025C72635808>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'repeat', '3', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C726FD288>, <__main__.Node object at 0x0000025C72635808>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C726FD288>
# <__main__.Node object at 0x0000025C72635808>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7266CD08>, 'repeat', '3', <__main__.Node object at 0x0000025C72731DC8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'repeat', '3', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'r', 13, 'i', 22, 'L', '28', 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'ron']
# My fields are the following:
# clockwise
# ron
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7266CD08>, 'repeat', '3', <__main__.Node object at 0x0000025C72731DC8>, <__main__.Node object at 0x0000025C7058B608>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'repeat', '3', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C72731DC8>, <__main__.Node object at 0x0000025C7058B608>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C72731DC8>
# <__main__.Node object at 0x0000025C7058B608>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7266CD08>, 'repeat', '3', <__main__.Node object at 0x0000025C726AD3C8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'repeat', '3', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'r', 13, 'i', 22, 'L', '28', 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'mark']
# My fields are the following:
# clockwise
# mark
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7266CD08>, 'repeat', '3', <__main__.Node object at 0x0000025C726AD3C8>, <__main__.Node object at 0x0000025C72744448>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'repeat', '3', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C726AD3C8>, <__main__.Node object at 0x0000025C72744448>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C726AD3C8>
# <__main__.Node object at 0x0000025C72744448>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7266CD08>, 'repeat', '3', <__main__.Node object at 0x0000025C70569FC8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'repeat', '3', 'L']
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'r', 13, 'i', 22, 'L', '28', 'd', 31]
# Original values:  ['repeat', '3', <__main__.Node object at 0x0000025C70569FC8>, 'end']
# My fields are the following:
# repeat
# 3
# <__main__.Node object at 0x0000025C70569FC8>
# end
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C7266CD08>, <__main__.Node object at 0x0000025C705DAC08>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C7266CD08>, <__main__.Node object at 0x0000025C705DAC08>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C7266CD08>
# <__main__.Node object at 0x0000025C705DAC08>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', 'repeat', '2', <__main__.Node object at 0x0000025C726B8508>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'repeat', '2', 'L']
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'r', 13, 'i', 22, 'L', '28', 'd', 31]
# Original values:  ['repeat', '2', <__main__.Node object at 0x0000025C726B8508>, 'end']
# My fields are the following:
# repeat
# 2
# <__main__.Node object at 0x0000025C726B8508>
# end
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', <__main__.Node object at 0x0000025C726D40C8>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'S']
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7', ';', 16]
# Original values:  [<__main__.Node object at 0x0000025C726D40C8>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C726D40C8>
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', <__main__.Node object at 0x0000025C726D4D48>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'c1']
# My fields are the following:
# clockwise
# c1
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', <__main__.Node object at 0x0000025C726D4D48>, <__main__.Node object at 0x0000025C72516208>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C726D4D48>, <__main__.Node object at 0x0000025C72516208>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C726D4D48>
# <__main__.Node object at 0x0000025C72516208>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', <__main__.Node object at 0x0000025C70584C08>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'c2']
# My fields are the following:
# clockwise
# c2
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', <__main__.Node object at 0x0000025C70584C08>, <__main__.Node object at 0x0000025C7267D188>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C70584C08>, <__main__.Node object at 0x0000025C7267D188>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C70584C08>
# <__main__.Node object at 0x0000025C7267D188>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', <__main__.Node object at 0x0000025C7263A948>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'c3']
# My fields are the following:
# clockwise
# c3
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', <__main__.Node object at 0x0000025C7263A948>, <__main__.Node object at 0x0000025C7262CF88>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C7263A948>, <__main__.Node object at 0x0000025C7262CF88>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C7263A948>
# <__main__.Node object at 0x0000025C7262CF88>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', <__main__.Node object at 0x0000025C72758A88>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'c4']
# My fields are the following:
# clockwise
# c4
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', <__main__.Node object at 0x0000025C72758A88>, <__main__.Node object at 0x0000025C7270EC88>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C72758A88>, <__main__.Node object at 0x0000025C7270EC88>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C72758A88>
# <__main__.Node object at 0x0000025C7270EC88>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, 'repeat', '13', <__main__.Node object at 0x0000025C7270E548>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'repeat', '13', 'L']
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'd', 31]
# Original values:  ['repeat', '13', <__main__.Node object at 0x0000025C7270E548>, 'end']
# My fields are the following:
# repeat
# 13
# <__main__.Node object at 0x0000025C7270E548>
# end
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72731748>, <__main__.Node object at 0x0000025C72541988>]
# vis stack:  ['size', '25', '25', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x0000025C72731748>, <__main__.Node object at 0x0000025C72541988>, ';']
# My fields are the following:
# <__main__.Node object at 0x0000025C72731748>
# <__main__.Node object at 0x0000025C72541988>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72724048>]
# vis stack:  ['size', '25', '25', 'begin', 'L']
# popping using reduction rule number:  1  rule:  P  ->  ziibLt  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 't', 14]
# Original values:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72724048>, 'halt']
# 6 attribute node found:  ['size', '25', '25', 'begin', <__main__.Node object at 0x0000025C72724048>, 'halt']
# My fields are the following:
# size
# 25
# 25
# begin
# <__main__.Node object at 0x0000025C72724048>
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  program
# STstack:  [<__main__.Node object at 0x0000025C72724E48>]
# vis stack:  ['P']
# lookahead is $, stack contents =  [0, 'P', '1']  and entry is  acc  so, accept
# *** VALID PROGRAM ***: program-string can be derived using the grammar

# %%
def direction_number(direction):  # directions = ["north =1", "east = 2", "south = 3", "west =4"]
    if direction == "north":
        return 1
    if direction == "east":
        return 2
    if direction == "south":
        return 3
    if direction == "west":
        return 4

# %%
def addMovement(node, prev_position, new_position, statement_list, symtable): # of form moveRelative c3 -5 0
    result = check_same_position(node, new_position, symtable)
    # first display them on the same square anyway
    varname = node.one
    xoffset = (int(scale_factor))*(new_position[0] - prev_position[0])
    yoffset = -1*((int(scale_factor)))*(new_position[1] - prev_position[1])   # -1 because JSAWAA interprets (0,30) as 30 units south!
    command = "moveRelative " + varname + " " + str(xoffset) + " " + str(yoffset)
    statement_list.append(command)
    
    if result == "don't continue":   # then delete them
        more_command = "remove " + varname
        statement_list.append(command)
        print("removed something")
    print("prev_position: ", prev_position, "new_position ", new_position)
    return
    #print("calculated offsets:(x,y) ", xoffset, " ", yoffset)

# %%
def check_same_position(node, new_pos, symtable):                      
    all_pos = [symtable[k][2] for k in range(len(symtable))]  # all positions in symtable 
    for i in range(len(all_pos)):
        if new_pos != [0,0] and new_pos == all_pos[i]:# if at least once this new position matches with another position already in symtable
            idx = i                               # index of other creature with new position
            if node.one != symtable[idx][1]:      # but not itself
                print("Something about to step on the same square as another!")# then we should get to this print, but I never did!
                if node.name == "cat" and symtable[idx][0] == "cat":
                    var = node.one
                    vars_found = [symtable[k][1] for k in range(len(symtable))]
                    cat_idx = vars_found.index(var)
                    symtable[cat_idx][1] = "REMOVED CAT"
                    print("REMOVED A CAT! SAME POSITION")
                    return "don't continue"
                elif node.name == "mouse" and symtable[idx][0] == "mouse":
                    hole_positions = [symtable[k][2] for k in range(len(symtable)) if symtable[k][0] == "hole"]
                    if new_pos in hole_positions:
                        return "continue"
                    var = node.one    # otherwise not in a hole
                    vars_found = [symtable[k][1] for k in range(len(symtable))]
                    mouse_idx = vars_found.index(var)
                    symtable[mouse_idx][1] = "REMOVED MOUSE"     # remove this mouse, not the other one
                    print("REMOVED A MOUSE! SAME POSITION")
                    return "don't continue"
                else:  # cat and mouse in same position
                    if node.name == "cat":    # then remove the mouse
                        symtable[idx][1] = "REMOVED MOUSE"
                        print("REMOVED A MOUSE! CAT ATE IT!")
                        return "don't continue"
                    else:# this var is a mouse, needs to be removed
                        var = node.one
                        vars_found = [symtable[k][1] for k in range(len(symtable))]
                        mouse_idx = vars_found.index(var)
                        symtable[mouse_idx][1] = "REMOVED MOUSE"
                        return "don't continue"
                        print("REMOVED A MOUSE! RAN INTO A CAT")
                    
    return "continue"

# %%
def addCatorMouse(node, statement_list, symtable):             # of form circle c6 205 61 7 black transparent
    resized_two = int(scale_factor)*(int(node.two))
    resized_three = int(scale_factor)*(int(node.three))
    command = "circle " + node.one + " " + str(resized_two) + " " + str(resized_three) + " "
    if node.name == "cat":
        command += str(15)    #diam = 15
        command += " black yellow"
    else:
        command += str(6)    #diam = 15
        command += " black blue"
    statement_list.append(command)
    
    # Update "variable in symtable to cat or mouse"
    vars_found = [symtable[k][1] for k in range(len(symtable))]
    var_idx = vars_found.index(node.one)    # var name
    symtable[var_idx][0] = node.name    # set variable to cat or mouse
    return

# %%
def addHole(node, statement_list, symtable):         # of form rectangle c6 205 61 7 10 black transparent
    holename = str(node.one)+str(node.two)
    symtable.append(["hole", holename, [int(node.one), int(node.two)], 0])  # hole same no direction
    
    resized_two = str(int(scale_factor)*(int(node.one)))
    resized_three = str(int(scale_factor)*(int(node.two)))
    command = "rectangle " + holename + " " + resized_two + " " + resized_three + " " + str(15) + " " + str(15) + " black black"
    statement_list.append(command)
    return

# %%
def JSAWAA_line(symtable, node, statement_list):
    x = int(node.one)
    y = int(node.two)
    for i in range(x):
        step = 15*i
        line = "line hline" +str(i)+ " 0 " + str(step) + " " + str(700) + " " + str(step) + " black"    # line hline2 0 20 450 20 black 
        statement_list.append(line)
        if i*15>800:
            break
    for j in range(y):
        step = 15*j
        line = "line vline" +str(j)+ " "+ str(step) + " 0 " + str(step) + " 600 black"
        statement_list.append(line)
        if j*15>800:
            break
    return

# %%
def update_symtable(symtable, node, statement_list):
    if node.name in ["cat", "mouse"]:
        print("Found cat or mouse node!")
        addCatorMouse(node, statement_list, symtable)
        var = node.one
        vars_found = [symtable[k][1] for k in range(len(symtable))]
        var_idx = vars_found.index(var)
        symtable[var_idx][2] = [int(node.two), int(node.three)]   # var two and three are initial cat and mouse positions
        direction = node.four.name    # orientation node is in var.four
        dir_num = direction_number(direction)
        symtable[var_idx][3] = dir_num
        #print(symtable)
    if node.name == "hole":
        print("Just need to put a hole at position x = : ", node.one, ", y = ", node.two, "!")
        addHole(node, statement_list, symtable)
    if node.name == "size":
        print("Just need to draw a grid of size x = : ", node.one, ", y = ", node.two, "!")
        JSAWAA_line(symtable, node, statement_list)
    if node.name =="clockwise":
        print("Found clockwise node!")
        var = node.one
        vars_found = [symtable[k][1] for k in range(len(symtable))]
        if var not in vars_found:
            print("Error, this cat or mouse has been removed before")
            return
        var_idx = vars_found.index(var)
        symtable[var_idx][3] +=1
        symtable[var_idx][3] = (symtable[var_idx][3])%4
        #print("current list of locations in table: ", [symtable[k][2] for k in range(len(symtable))])
    if node.name == "move":
        print("Found move node!")
        print("current list of locations in table: ", [symtable[k][2] for k in range(len(symtable))])
        var = node.one
        vars_found = [symtable[k][1] for k in range(len(symtable))]
        if var not in vars_found:
            print("Error, this cat or mouse has been removed before")
            return
        var_idx = vars_found.index(var)
        prev_position = symtable[var_idx][2].copy()
        dir_num = symtable[var_idx][3]        # need to move in this direction
        if node.two == "null":
            if (dir_num %2)==0:             #east, west are 0 mod 2; north,south are 1 mod 2; 
                if (dir_num ==2):
                    symtable[var_idx][2][0] +=1    # east
                else:
                    symtable[var_idx][2][0] -=1    # west
            else:
                if (dir_num ==1):
                    symtable[var_idx][2][1] +=1    # north
                else:
                    symtable[var_idx][2][1] -=1    # south
        else:
            if (dir_num %2)==0:             #east, west are 0 mod 2; north,south are 1 mod 2; 
                if (dir_num ==2):
                    symtable[var_idx][2][0] +=int(node.two)    # east
                else:
                    symtable[var_idx][2][0] -=int(node.two)   # west
            else:
                if (dir_num ==1):
                    symtable[var_idx][2][1] +=int(node.two)    # north
                else:
                    symtable[var_idx][2][1] -=int(node.two)    # south
        new_position = symtable[var_idx][2]
        addMovement(node, prev_position, new_position, statement_list, symtable)
        #print(symtable)
    return

# %%
def traverse(symtable, node, statement_list):
    a = node.name
    b = node.one
    c = node.two
    d = node.three
    e = node.four
    #print(a, b, c, d, e)
    if type(a) is Node:
        if a.name == "repeat":
            print("#####Found repeat node!: ", a.one, " many times")
            for i in range(int(a.one)):   # a.one = how many times to repeat
                update_symtable(symtable, a.two, statement_list)
                traverse(symtable, a.two, statement_list)
        else:
            update_symtable(symtable, a, statement_list)
            traverse(symtable, a, statement_list)
    if type(b) is Node:
        if b.name == "repeat":
            print("#####Found repeat node: ", b.one, " many times")
            for i in range(int(b.one)):   # a.one = how many times to repeat
                update_symtable(symtable, b.two, statement_list)
                traverse(symtable, b.two, statement_list)
        else:
            update_symtable(symtable, b, statement_list)
            traverse(symtable, b, statement_list)
    if type(c) is Node:
        if c.name == "repeat":
            print("#####Found repeat node: ", c.one, " many times")
            for i in range(int(c.one)):   # a.one = how many times to repeat
                update_symtable(symtable, c.two, statement_list)
                traverse(symtable, c.two, statement_list)
        else:
            update_symtable(symtable, c, statement_list)
            traverse(symtable, c, statement_list)
    if type(d) is Node:
        if d.name == "repeat":
            print("#####Found repeat node: ", d.one, " many times")
            for i in range(int(d.one)):   # a.one = how many times to repeat
                update_symtable(symtable, d.two, statement_list)
                traverse(symtable, d.two, statement_list)
        else:
            update_symtable(symtable, d, statement_list)
            traverse(symtable, d, statement_list)
    if type(e) is Node:
        if e.name == "repeat":
            print("#####Found repeat node: ", e.one, " many times")
            for i in range(int(e.one)):   # a.one = how many times to repeat
                update_symtable(symtable, e.two, statement_list)
                traverse(symtable, e.two, statement_list)
        else:
            update_symtable(symtable, e, statement_list)
            traverse(symtable, e, statement_list)
    else:
        return

# %%
node = ststack[0]                                                             ### THIRD/FINAL RUN
statement_list = []
scale_factor = input("Please enter a SCALE FACTOR to scale movements of cat and mice: ") # CHANGE THIS DEPENDING ON THE PROGRAM!
traverse(symtable, node, statement_list)
# Out:
# Please enter a SCALE FACTOR to scale movements of cat and mice: 5
# Just need to draw a grid of size x = :  25 , y =  25 !
# Found cat or mouse node!
# Found cat or mouse node!
# Found cat or mouse node!
# Found cat or mouse node!
# Just need to put a hole at position x = :  13 , y =  13 !
# Found cat or mouse node!
# Found cat or mouse node!
# Found cat or mouse node!
# Found cat or mouse node!
# #####Found repeat node:  13  many times
# #####Found repeat node:  2  many times
# Found move node!
# current list of locations in table:  [[15, 15], [11, 15], [11, 11], [15, 11],

# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found move node!
# current list of locations in table:  [[12, 15], [11, 18], [14, 11], [15, 8], [4, 1], [6, 3], [21, 24], [15, 18], [13, 13]]
# prev_position:  [12, 15] new_position  [11, 15]
# Found move node!
# current list of locations in table:  [[11, 15], [11, 18], [14, 11], [15, 8], [4, 1], [6, 3], [21, 24], [15, 18], [13, 13]]
# prev_position:  [11, 18] new_position  [11, 19]
# Found move node!
# current list of locations in table:  [[11, 15], [11, 19], [14, 11], [15, 8], [4, 1], [6, 3], [21, 24], [15, 18], [13, 13]]
# prev_position:  [14, 11] new_position  [15, 11]
# Found move node!
# current list of locations in table:  [[11, 15], [11, 19], [15, 11], [15, 8], [4, 1], [6, 3], [21, 24], [15, 18], [13, 13]]
# prev_position:  [15, 8] new_position  [15, 7]
# Found move node!
# current list of locations in table:  [[11, 15], [11, 19], [15, 11], [15, 7], [4, 1], [6, 3], [21, 24], [15, 18], [13, 13]]
# prev_position:  [4, 1] new_position  [4, 0]
# Found move node!
# current list of locations in table:  [[11, 15], [11, 19], [15, 11], [15, 7], [4, 0], [6, 3], [21, 24], [15, 18], [13, 13]]
# prev_position:  [6, 3] new_position  [6, 2]
# Found move node!
# current list of locations in table:  [[11, 15], [11, 19], [15, 11], [15, 7], [4, 0], [6, 2], [21, 24], [15, 18], [13, 13]]
# prev_position:  [21, 24] new_position  [21, 25]
# Found move node!
# current list of locations in table:  [[11, 15], [11, 19], [15, 11], [15, 7], [4, 0], [6, 2], [21, 25], [15, 18], [13, 13]]
# prev_position:  [15, 18] new_position  [15, 19]
# #####Found repeat node:  3  many times
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# #####Found repeat node:  2  many times
# Found move node!
# current list of locations in table:  [[11, 15], [11, 19], [15, 11], [15, 7], [4, 0], [6, 2], [21, 25], [15, 19], [13, 13]]
# prev_position:  [11, 15] new_position  [11, 16]
# Found move node!
# current list of locations in table:  [[11, 16], [11, 19], [15, 11], [15, 7], [4, 0], [6, 2], [21, 25], [15, 19], [13, 13]]
# prev_position:  [11, 19] new_position  [12, 19]
# Found move node!
# current list of locations in table:  [[11, 16], [12, 19], [15, 11], [15, 7], [4, 0], [6, 2], [21, 25], [15, 19], [13, 13]]
# prev_position:  [15, 11] new_position  [15, 10]
# Found move node!
# current list of locations in table:  [[11, 16], [12, 19], [15, 10], [15, 7], [4, 0], [6, 2], [21, 25], [15, 19], [13, 13]]
# prev_position:  [15, 7] new_position  [14, 7]
# Found move node!
# current list of locations in table:  [[11, 16], [12, 19], [15, 10], [14, 7], [4, 0], [6, 2], [21, 25], [15, 19], [13, 13]]
# prev_position:  [4, 0] new_position  [5, 0]
# Found move node!
# current list of locations in table:  [[11, 16], [12, 19], [15, 10], [14, 7], [5, 0], [6, 2], [21, 25], [15, 19], [13, 13]]
# prev_position:  [6, 2] new_position  [7, 2]
# Found move node!
# current list of locations in table:  [[11, 16], [12, 19], [15, 10], [14, 7], [5, 0], [7, 2], [21, 25], [15, 19], [13, 13]]
# prev_position:  [21, 25] new_position  [20, 25]
# Found move node!
# current list of locations in table:  [[11, 16], [12, 19], [15, 10], [14, 7], [5, 0], [7, 2], [20, 25], [15, 19], [13, 13]]
# prev_position:  [15, 19] new_position  [14, 19]
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found move node!
# current list of locations in table:  [[11, 16], [12, 19], [15, 10], [14, 7], [5, 0], [7, 2], [20, 25], [14, 19], [13, 13]]
# prev_position:  [11, 16] new_position  [11, 17]
# Found move node!
# current list of locations in table:  [[11, 17], [12, 19], [15, 10], [14, 7], [5, 0], [7, 2], [20, 25], [14, 19], [13, 13]]
# prev_position:  [12, 19] new_position  [13, 19]
# Found move node!
# current list of locations in table:  [[11, 17], [13, 19], [15, 10], [14, 7], [5, 0], [7, 2], [20, 25], [14, 19], [13, 13]]
# prev_position:  [15, 10] new_position  [15, 9]
# Found move node!
# current list of locations in table:  [[11, 17], [13, 19], [15, 9], [14, 7], [5, 0], [7, 2], [20, 25], [14, 19], [13, 13]]
# prev_position:  [14, 7] new_position  [13, 7]
# Found move node!
# current list of locations in table:  [[11, 17], [13, 19], [15, 9], [13, 7], [5, 0], [7, 2], [20, 25], [14, 19], [13, 13]]
# prev_position:  [5, 0] new_position  [5, -1]
# Found move node!
# current list of locations in table:  [[11, 17], [13, 19], [15, 9], [13, 7], [5, -1], [7, 2], [20, 25], [14, 19], [13, 13]]
# prev_position:  [7, 2] new_position  [7, 1]
# Found move node!
# current list of locations in table:  [[11, 17], [13, 19], [15, 9], [13, 7], [5, -1], [7, 1], [20, 25], [14, 19], [13, 13]]
# prev_position:  [20, 25] new_position  [20, 26]
# Found move node!
# current list of locations in table:  [[11, 17], [13, 19], [15, 9], [13, 7], [5, -1], [7, 1], [20, 26], [14, 19], [13, 13]]
# prev_position:  [14, 19] new_position  [14, 20]
# #####Found repeat node:  3  many times
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found move node!
# current list of locations in table:  [[11, 17], [13, 19], [15, 9], [13, 7], [5, -1], [7, 1], [20, 26], [14, 20], [13, 13]]
# prev_position:  [11, 17] new_position  [11, 18]
# Found move node!
# current list of locations in table:  [[11, 18], [13, 19], [15, 9], [13, 7], [5, -1], [7, 1], [20, 26], [14, 20], [13, 13]]
# prev_position:  [13, 19] new_position  [14, 19]
# Found move node!
# current list of locations in table:  [[11, 18], [14, 19], [15,

# #####Found repeat node:  3  many times
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found move node!
# current list of locations in table:  [[11, 17], [13, 19], [15, 9], [13, 7], [13, -9], [15, -7], [12, 34], [6, 28], [13, 13]]
# prev_position:  [11, 17] new_position  [11, 18]
# Found move node!
# current list of locations in table:  [[11, 18], [13, 19], [15, 9], [13, 7], [13, -9], [15, -7], [12, 34], [6, 28], [13, 13]]
# prev_position:  [13, 19] new_position  [14, 19]
# Found move node!
# current list of locations in table:  [[11, 18], [14, 19], [15, 9], [13, 7], [13, -9], [15, -7], [12, 34], [6, 28], [13, 13]]
# prev_position:  [15, 9] new_position  [15, 8]
# Found move node!
# current list of locations in table:  [[11, 18], [14, 19], [15, 8], [13, 7], [13, -9], [15, -7], [12, 34], [6, 28], [13, 13]]
# prev_position:  [13, 7] new_position  [12, 7]
# Found move node!
# current list of locations in table:  [[11, 18], [14, 19], [15, 8], [12, 7], [13, -9], [15, -7], [12, 34], [6, 28], [13, 13]]
# prev_position:  [13, -9] new_position  [14, -9]
# Found move node!
# current list of locations in table:  [[11, 18], [14, 19], [15, 8], [12, 7], [14, -9], [15, -7], [12, 34], [6, 28], [13, 13]]
# prev_position:  [15, -7] new_position  [16, -7]
# Found move node!
# current list of locations in table:  [[11, 18], [14, 19], [15, 8], [12, 7], [14, -9], [16, -7], [12, 34], [6, 28], [13, 13]]
# prev_position:  [12, 34] new_position  [11, 34]
# Found move node!
# current list of locations in table:  [[11, 18], [14, 19], [15, 8], [12, 7], [14, -9], [16, -7], [11, 34], [6, 28], [13, 13]]
# prev_position:  [6, 28] new_position  [5, 28]
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found move node!
# current list of locations in table:  [[11, 18], [14, 19], [15, 8], [12, 7], [14, -9], [16, -7], [11, 34], [5, 28], [13, 13]]
# prev_position:  [11, 18] new_position  [11, 19]
# Found move node!
# current list of locations in table:  [[11, 19], [14, 19], [15, 8], [12, 7], [14, -9], [16, -7], [11, 34], [5, 28], [13, 13]]
# prev_position:  [14, 19] new_position  [15, 19]
# Found move node!
# current list of locations in table:  [[11, 19], [15, 19], [15, 8], [12, 7], [14, -9], [16, -7], [11, 34], [5, 28], [13, 13]]
# prev_position:  [15, 8] new_position  [15, 7]
# Found move node!
# current list of locations in table:  [[11, 19], [15, 19], [15, 7], [12, 7], [14, -9], [16, -7], [11, 34], [5, 28], [13, 13]]
# prev_position:  [12, 7] new_position  [11, 7]
# Found move node!
# current list of locations in table:  [[11, 19], [15, 19], [15, 7], [11, 7], [14, -9], [16, -7], [11, 34], [5, 28], [13, 13]]
# prev_position:  [14, -9] new_position  [14, -10]
# Found move node!
# current list of locations in table:  [[11, 19], [15, 19], [15, 7], [11, 7], [14, -10], [16, -7], [11, 34], [5, 28], [13, 13]]
# prev_position:  [16, -7] new_position  [16, -8]
# Found move node!
# current list of locations in table:  [[11, 19], [15, 19], [15, 7], [11, 7], [14, -10], [16, -8], [11, 34], [5, 28], [13, 13]]
# prev_position:  [11, 34] new_position  [11, 35]
# Found move node!
# current list of locations in table:  [[11, 19], [15, 19], [15, 7], [11, 7], [14, -10], [16, -8], [11, 35], [5, 28], [13, 13]]
# prev_position:  [5, 28] new_position  [5, 29]
# #####Found repeat node:  3  many times
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# #####Found repeat node:  2  many times
# Found move node!
# current list of locations in table:  [[11, 19], [15, 19], [15, 7], [11, 7], [14, -10], [16, -8], [11, 35], [5, 29], [13, 13]]
# prev_position:  [11, 19] new_position  [12, 19]
# Found move node!
# current list of locations in table:  [[12, 19], [15, 19], [15, 7], [11, 7], [14, -10], [16, -8], [11, 35], [5, 29], [13, 13]]
# prev_position:  [15, 19] new_position  [15, 18]
# Found move node!
# current list of locations in table:  [[12, 19], [15, 18], [15, 7], [11, 7], [14, -10], [16, -8], [11, 35], [5, 29], [13, 13]]
# prev_position:  [15, 7] new_position  [14, 7]
# Found move node!
# current list of locations in table:  [[12, 19], [15, 18], [14, 7], [11, 7], [14, -10], [16, -8], [11, 35], [5, 29], [13, 13]]
# prev_position:  [11, 7] new_position  [11, 8]
# Found move node!
# current list of locations in table:  [[12, 19], [15, 18], [14, 7], [11, 8], [14, -10], [16, -8], [11, 35], [5, 29], [13, 13]]
# prev_position:  [14, -10] new_position  [15, -10]
# Found move node!
# current list of locations in table:  [[12, 19], [15, 18], [14, 7], [11, 8], [15, -10], [16, -8], [11, 35], [5, 29], [13, 13]]
# prev_position:  [16, -8] new_position  [17, -8]
# Found move node!
# current list of locations in table:  [[12, 19], [15, 18], [14, 7], [11, 8], [15, -10], [17, -8], [11, 35], [5, 29], [13, 13]]
# prev_position:  [11, 35] new_position  [10, 35]
# Found move node!
# current list of locations in table:  [[12, 19], [15, 18], [14, 7], [11, 8], [15, -10], [17, -8], [10, 35], [5, 29], [13, 13]]
# prev_position:  [5, 29] new_position  [4, 29]
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found move node!
# current list of locations in table:  [

# Found move node!
# current list of locations in table:  [[15, 19], [15, 15], [11, 7], [11, 11], [24, -20], [26, -17], [1, 44], [-5, 38], [13, 13]]
# prev_position:  [26, -17] new_position  [26, -18]
# Found move node!
# current list of locations in table:  [[15, 19], [15, 15], [11, 7], [11, 11], [24, -20], [26, -18], [1, 44], [-5, 38], [13, 13]]
# prev_position:  [1, 44] new_position  [1, 45]
# Found move node!
# current list of locations in table:  [[15, 19], [15, 15], [11, 7], [11, 11], [24, -20], [26, -18], [1, 45], [-5, 38], [13, 13]]
# prev_position:  [-5, 38] new_position  [-5, 39]
# #####Found repeat node:  3  many times
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# #####Found repeat node:  2  many times
# Found move node!
# current list of locations in table:  [[15, 19], [15, 15], [11, 7], [11, 11], [24, -20], [26, -18], [1, 45], [-5, 39], [13, 13]]
# prev_position:  [15, 19] new_position  [15, 18]
# Found move node!
# current list of locations in table:  [[15, 18], [15, 15], [11, 7], [11, 11], [24, -20], [26, -18], [1, 45], [-5, 39], [13, 13]]
# prev_position:  [15, 15] new_position  [14, 15]
# Found move node!
# current list of locations in table:  [[15, 18], [14, 15], [11, 7], [11, 11], [24, -20], [26, -18], [1, 45], [-5, 39], [13, 13]]
# prev_position:  [11, 7] new_position  [11, 8]
# Found move node!
# current list of locations in table:  [[15, 18], [14, 15], [11, 8], [11, 11], [24, -20], [26, -18], [1, 45], [-5, 39], [13, 13]]
# prev_position:  [11, 11] new_position  [12, 11]
# Found move node!
# current list of locations in table:  [[15, 18], [14, 15], [11, 8], [12, 11], [24, -20], [26, -18], [1, 45], [-5, 39], [13, 13]]
# prev_position:  [24, -20] new_position  [25, -20]
# Found move node!
# current list of locations in table:  [[15, 18], [14, 15], [11, 8], [12, 11], [25, -20], [26, -18], [1, 45], [-5, 39], [13, 13]]
# prev_position:  [26, -18] new_position  [27, -18]
# Found move node!
# current list of locations in table:  [[15, 18], [14, 15], [11, 8], [12, 11], [25, -20], [27, -18], [1, 45], [-5, 39], [13, 13]]
# prev_position:  [1, 45] new_position  [0, 45]
# Found move node!
# current list of locations in table:  [[15, 18], [14, 15], [11, 8], [12, 11], [25, -20], [27, -18], [0, 45], [-5, 39], [13, 13]]
# prev_position:  [-5, 39] new_position  [-6, 39]
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found move node!
# current list of locations in table:  [[15, 18], [14, 15], [11, 8], [12, 11], [25, -20], [27, -18], [0, 45], [-6, 39], [13, 13]]
# prev_position:  [15, 18] new_position  [15, 17]
# Found move node!
# current list of locations in table:  [[15, 17], [14, 15], [11, 8], [12, 11], [25, -20], [27, -18], [0, 45], [-6, 39], [13, 13]]
# prev_position:  [14, 15] new_position  [13, 15]
# Found move node!
# current list of locations in table:  [[15, 17], [13, 15], [11, 8], [12, 11], [25, -20], [27, -18], [0, 45], [-6, 39], [13, 13]]
# prev_position:  [11, 8] new_position  [11, 9]
# Found move node!
# current list of locations in table:  [[15, 17], [13, 15], [11, 9], [12, 11], [25, -20], [27, -18], [0, 45], [-6, 39], [13, 13]]
# prev_position:  [12, 11] new_position  [13, 11]
# Found move node!
# current list of locations in table:  [[15, 17], [13, 15], [11, 9], [13, 11], [25, -20], [27, -18], [0, 45], [-6, 39], [13, 13]]
# prev_position:  [25, -20] new_position  [25, -21]
# Found move node!
# current list of locations in table:  [[15, 17], [13, 15], [11, 9], [13, 11], [25, -21], [27, -18], [0, 45], [-6, 39], [13, 13]]
# prev_position:  [27, -18] new_position  [27, -19]
# Found move node!
# current list of locations in table:  [[15, 17], [13, 15], [11, 9], [13, 11], [25, -21], [27, -19], [0, 45], [-6, 39], [13, 13]]
# prev_position:  [0, 45] new_position  [0, 46]
# Found move node!
# current list of locations in table:  [[15, 17], [13, 15], [11, 9], [13, 11], [25, -21], [27, -19], [0, 46], [-6, 39], [13, 13]]
# prev_position:  [-6, 39] new_position  [-6, 40]
# #####Found repeat node:  3  many times
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found move node!
# current list of locations in table:  [[15, 17], [13, 15], [11, 9], [13, 11], [25, -21], [27, -19], [0, 46], [-6, 40], [13, 13]]
# prev_position:  [15, 17] new_position  [15, 16]
# Found move node!
# current list of locations in table:  [[15, 16], [13, 15], [11, 9], [13, 11], [25, -21], [27, -19], [0, 46], [-6, 40], [13, 13]]
# prev_position:  [13, 15] new_position  [12, 15]
# Found move node!
# current list of locations in table:  [[15, 16], [12, 15], [11, 9], [13, 11], [25, -21], [27, -19], [0, 46], [-6, 40], [13, 13]]
# prev_position:  [11, 9] new_position  [11, 10]
# Found move node!
# current list of locations in table:  [[15, 16], [12, 15], [11, 10], [13, 11], [25, -21], [27, -19], [0, 46], [-6, 40], [13, 13]]
# prev_position:  [13, 11] new_position  [14, 11]
# Found move node!
# current list of locations in table:  [[15, 16], [12, 15], [11, 10], [14, 11], [25, -21], [27, -19], [0, 46], [-6, 40], [13, 13]]
# prev_position:  [25, -21] new_position  [26, -21]
# Found move node!
# current list of locations in table:  [[15, 16], [12, 15], [11, 10], [14, 11], [26, -21], [27, -19], [0, 46], [-6, 40], [13, 13]]
# prev_position:  [27, -19] new_position  [28, -19]
# Found move node!
# current list of locations in table:  [[15, 16], [12, 15], [11, 10], [14, 11], [26, -21], [28, -19], [0, 46], [-6, 40], [13, 13]]
# prev_position:  [0, 46] new_position  [-1, 46]
# Found move node!
# current list of locations in table:  [[15, 16], [12, 15], [11, 10], [14, 11], [26, -21], [28, -19], [-1, 46], [-6, 40], [13, 13]]
# prev_position:  [-6, 40] new_position  [-7, 40]
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found move node!
# current list of locations in table:  [[15, 16], [12, 15], [11, 10], [14, 11], [26, -21], [28, -19], [-1, 46], [-7, 40], [13, 13]]
# prev_position:  [15, 16] new_position  [15, 15]
# Found move node!
# current list of locations in table:  [[15, 15], [12, 15], [11, 10], [14, 11], [26, -21], [28, -19], [-1, 46], [-7, 40], [13, 13]]
# prev_position:  [12, 15] new_position  [11, 15]
# Found move node!
# current list of locations in table:  [[15, 15], [11, 15], [11, 10], [14, 11], [26, -21], [28, -19], [-1, 46], [-7, 40], [13, 13]]
# prev_position:  [11, 10] new_position  [11, 11]
# Found move node!
# current list of locations in table:  [[15, 15], [11, 15], [11, 11], [14, 11], [26, -21], [28, -19], [-1, 46], [-7, 40], [13, 13]]
# prev_position:  [14, 11] new_position  [15, 11]
# Found move node!
# current list of locations in table:  [[15, 15], [11, 15], [11, 11], [15, 11], [26, -21], [28, -19], [-1, 46], [-7, 40], [13, 13]]
# prev_position:  [26, -21] new_position  [26, -22]
# Found move node!
# current list of locations in table:  [[15, 15], [11, 15], [11, 11], [15, 11], [26, -22], [28, -19], [-1, 46], [-7, 40], [13, 13]]
# prev_position:  [28, -19] new_position  [28, -20]
# Found move node!
# current list of locations in table:  [[15, 15], [11, 15], [11, 11], [15, 11], [26, -22], [28, -20], [-1, 46], [-7, 40], [13, 13]]
# prev_position:  [-1, 46] new_position  [-1, 47]
# Found move node!
# current list of locations in table:  [[15, 15], [11, 15], [11, 11], [15, 11], [26, -22], [28, -20], [-1, 47], [-7, 40], [13, 13]]
# prev_position:  [-7, 40] new_position  [-7, 41]
# #####Found repeat node:  3  many times
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# #####Found repeat node:  2  many times
# Found move node!
# current list of locations in table:  [[15, 15], [11, 15], [11, 11], [15, 11], [26, -22], [28, -20], [-1, 47], [-7, 41], [13, 13]]
# prev_position:  [15, 15] new_position  [14, 15]
# Found move node!
# current list of locations in table:  [[14, 15], [11, 15], [11, 11], [15, 11], [26, -22], [28, -20], [-1, 47], [-7, 41], [13, 13]]
# prev_position:  [11, 15] new_position  [11, 16]
# Found move node!
# current list of locations in table:  [[14, 15], [11, 16], [11, 11], [15, 11], [26, -22], [28, -20], [-1, 47], [-7, 41], [13, 13]]
# prev_position:  [11, 11] new_position  [12, 11]
# Found move node!
# current list of locations in table:  [[14, 15], [11, 16], [12, 11], [15, 11], [26, -22], [28, -20], [-1, 47], [-7, 41], [13, 13]]
# prev_position:  [15, 11] new_position  [15, 10]
# Found move node!
# current list of locations in table:  [[14, 15], [11, 16], [12, 11], [15, 10], [26, -22], [28, -20], [-1, 47], [-7, 41], [13, 13]]
# prev_position:  [26, -22] new_position  [27, -22]
# Found move node!
# current list of locations in table:  [[14, 15], [11, 16], [12, 11], [15, 10], [27, -22], [28, -20], [-1, 47], [-7, 41], [13, 13]]
# prev_position:  [28, -20] new_position  [29, -20]
# Found move node!
# current list of locations in table:  [[14, 15], [11, 16], [12, 11], [15, 10], [27, -22], [29, -20], [-1, 47], [-7, 41], [13, 13]]
# prev_position:  [-1, 47] new_position  [-2, 47]
# Found move node!
# current list of locations in table:  [[14, 15], [11, 16], [12, 11], [15, 10], [27, -22], [29, -20], [-2, 47], [-7, 41], [13, 13]]
# prev_position:  [-7, 41] new_position  [-8, 41]
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found move node!
# current list of locations in table:  [[14, 15], [11, 16], [12, 11], [15, 10], [27, -22], [29, -20], [-2, 47], [-8, 41], [13, 13]]
# prev_position:  [14, 15] new_position  [13, 15]
# Found move node!
# current list of locations in table:  [[13, 15], [11, 16], [12, 11], [15, 10], [27, -22], [29, -20], [-2, 47], [-8, 41], [13, 13]]
# prev_position:  [11, 16] new_position  [11, 17]
# Found move node!
# current list of locations in table:  [[13, 15], [11, 17], [12, 11], [15, 10], [27, -22], [29, -20], [-2, 47], [-8, 41], [13, 13]]
# prev_position:  [12, 11] new_position  [13, 11]
# Found move node!
# current list of locations in table:  [[13, 15], [11, 17], [13, 11], [15, 10], [27, -22], [29, -20], [-2, 47], [-8, 41], [13, 13]]
# prev_position:  [15, 10] new_position  [15, 9]
# Found move node!
# current list of locations in table:  [[13, 15], [11, 17], [13, 11], [15, 9], [27, -22], [29, -20], [-2, 47], [-8, 41], [13, 13]]
# prev_position:  [27, -22] new_position  [27, -23]
# Found move node!
# current list of locations in table:  [[13, 15], [11, 17], [13, 11], [15, 9], [27, -23], [29, -20], [-2, 47], [-8, 41], [13, 13]]
# prev_position:  [29, -20] new_position  [29, -21]
# Found move node!
# current list of locations in table:  [[13, 15], [11, 17], [13, 11], [15, 9], [27, -23], [29, -21], [-2, 47], [-8, 41], [13, 13]]
# prev_position:  [-2, 47] new_position  [-2, 48]
# Found move node!
# current list of locations in table:  [[13, 15], [11, 17], [13, 11], [15, 9], [27, -23], [29, -21], [-2, 48], [-8, 41], [13, 13]]
# prev_position:  [-8, 41] new_position  [-8, 42]
# #####Found repeat node:  3  many times
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found move node!
# current list of locations in table:  [[13, 15], [11, 17], [13, 11], [15, 9], [27, -23], [29, -21], [-2, 48], [-8, 42], [13, 13]]
# prev_position:  [13, 15] new_position  [12, 15]
# Found move node!
# current list of locations in table:  [[12, 15], [11, 17], [13, 11], [15, 9], [27, -23], [29, -21], [-2, 48], [-8, 42], [13, 13]]
# prev_position:  [11, 17] new_position  [11, 18]
# Found move node!
# current list of locations in table:  [[12, 15], [11, 18], [13, 11], [15, 9], [27, -23], [29, -21], [-2, 48], [-8, 42], [13, 13]]
# prev_position:  [13, 11] new_position  [14, 11]
# Found move node!
# current list of locations in table:  [[12, 15], [11, 18], [14, 11], [15, 9], [27, -23], [29, -21], [-2, 48], [-8, 42], [13, 13]]
# prev_position:  [15, 9] new_position  [15, 8]
# Found move node!
# current list of locations in table:  [[12, 15], [11, 18], [14, 11], [15, 8], [27, -23], [29, -21], [-2, 48], [-8, 42], [13, 13]]
# prev_position:  [27, -23] new_position  [28, -23]
# Found move node!
# current list of locations in table:  [[12, 15], [11, 18], [14, 11], [15, 8], [28, -23], [29, -21], [-2, 48], [-8, 42], [13, 13]]
# prev_position:  [29, -21] new_position  [30, -21]
# Found move node!
# current list of locations in table:  [[12, 15], [11, 18], [14, 11], [15, 8], [28, -23], [30, -21], [-2, 48], [-8, 42], [13, 13]]
# prev_position:  [-2, 48] new_position  [-3, 48]
# Found move node!
# current list of locations in table:  [[12, 15], [11, 18], [14, 11], [15, 8], [28, -23], [30, -21], [-3, 48], [-8, 42], [13, 13]]
# prev_position:  [-8, 42] new_position  [-9, 42]
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found move node!
# current list of locations in table:  [[12, 15], [11, 18], [14, 11], [15, 8], [28, -23], [30, -21], [-3, 48], [-9, 42], [13, 13]]
# prev_position:  [12, 15] new_position  [11, 15]
# Found move node!
# current list of locations in table:  [[11, 15], [11, 18], [14, 11], [15, 8], [28, -23], [30, -21], [-3, 48], [-9, 42], [13, 13]]
# prev_position:  [11, 18] new_position  [11, 19]
# Found move node!
# current list of locations in table:  [[11, 15], [11, 19], [14, 11], [15, 8], [28, -23], [30, -21], [-3, 48], [-9, 42], [13, 13]]
# prev_position:  [14, 11] new_position  [15, 11]
# Found move node!
# current list of locations in table:  [[11, 15], [11, 19], [15, 11], [15, 8], [28, -23], [30, -21], [-3, 48], [-9, 42], [13, 13]]
# prev_position:  [15, 8] new_position  [15, 7]
# Found move node!
# current list of locations in table:  [[11, 15], [11, 19], [15, 11], [15, 7], [28, -23], [30, -21], [-3, 48], [-9, 42], [13, 13]]
# prev_position:  [28, -23] new_position  [28, -24]
# Found move node!
# current list of locations in table:  [[11, 15], [11, 19], [15, 11], [15, 7], [28, -24], [30, -21], [-3, 48], [-9, 42], [13, 13]]
# prev_position:  [30, -21] new_position  [30, -22]
# Found move node!
# current list of locations in table:  [[11, 15], [11, 19], [15, 11], [15, 7], [28, -24], [30, -22], [-3, 48], [-9, 42], [13, 13]]
# prev_position:  [-3, 48] new_position  [-3, 49]
# Found move node!
# current list of locations in table:  [[11, 15], [11, 19], [15, 11], [15, 7], [28, -24], [30, -22], [-3, 49], [-9, 42], [13, 13]]
# prev_position:  [-9, 42] new_position  [-9, 43]
# #####Found repeat node:  3  many times
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!

# %%
# print(statement_list)

# %%
out_fname = "outfile_" + filename + str(scale_factor) + ".txt"    # DEPENDS ON SCALE FACTOR AND .mc PROGRAM RAN!
f = open(out_fname, "w")
for line in statement_list:
    f.write(line)
    f.write("\n")
f.close()

# %%
from tabulate import tabulate
print(tabulate(symtable, headers=["TYPE","CH VALUE", "POSITION", "ORIENTATION"]))

# %% [markdown]
# ### Thank you!
