# %% [markdown]
# ### Welcome to Project 3: Building an interpreter and visualizations for a Cat and Mouse program

# %%
# filename later gets updated to the .mc filename input by user

filepath = ""
extension = ".txt"
filename = "parsedata" + extension            ## FIRST RUN

# %%
def makeTable(filename, LRtable):
    # Open parsedata.txt and do some file processing
    # This file is same for every .mc file to be processed, so it is done just once at the beginning
    file = open(filename, "r")
    idx = 0
    for line in file:
        lookaheads = line.split('&')
        LRtable.append(lookaheads)   # keep \n for now
        if idx == 38:
            break
        idx +=1
    idx = 0
    for line in file:
        lookaheads = line.split('&')[1:]         # get rid of the extra numbered row for variables
        LRtable[idx] = LRtable[idx] + lookaheads  # we'll concatenate it with the row of terminals already numbered
        idx +=1
        
    n = LRtable[0].index('$\n')
    for i in range(len(LRtable)):
        withNln =  LRtable[i][-1]
        LRtable[i][-1] = withNln[0:-1]
        withNln2 =  LRtable[i][n]
        LRtable[i][n] = withNln2[0:-1]
    return LRtable
    #print(LRtable)

# %%
table = []
LRtable = makeTable(filename, table)  ### FIRST RUN
LRtable2 = LRtable.copy()

# print(len(LRtable[0]))
# print(len(LRtable[1]))

# %%
# a nice visualization of the table

# from tabulate import tabulate
# print(tabulate(LRtable))
# Out:
# --  --  ---  --  ---  ---  --  ---  --  ---  ---  ---  ---  ---  ---  ---  ---  ---  ---  -  --  --  --
#     z   i    b   t    ;    c   v    m   h    o    l    r    d    n    s    e    w    $    P  L   S   D
# 0   s2                                                                                    1
# 1                                                                                    acc
# 2       s3
# 3       s4
# 4            s5
# 5                          s8       s9  s10  s11  s12  s13                                   6   7
# 6                s14       s8       s9  s10  s11  s12  s13                                       15
# 7                     s16
# 8                              s17
# 9                              s18
# 10      s19
# 11                             s20
# 12                             s21
# 13      s22
# 14                                                                                   r1
# 15                    s23
# 16               r2        r2       r2  r2   r2   r2   r2   r2
# 17      s24
# 18      s25
# 19      s26
# 20      s27           r7
# 21                    r9
# 22                         s8       s9  s10  s11  s12  s13                                   28  7
# 23               r3        r3       r3  r3   r3   r3   r3   r3
# 24      s29
# 25      s30
# 26                    r6
# 27                    r8
# 28                         s8       s9  s10  s11  s12  s13  s31                                  15
# 29                                                               s33  s34  s35  s36                  32
# 30                                                               s33  s34  s35  s36                  37
# 31                    r10
# 32                    r4
# 33                    r11
# 34                    r12
# 35                    r13
# 36                    r14
# 37                    r5
# --  --  ---  --  ---  ---  --  ---  --  ---  ---  ---  ---  ---  ---  ---  ---  ---  ---  -  --  --  --

# %%
# functions from project 1 - works as described there

def valid_int(word, digits):
    try:
        int(word)
    except ValueError:
        return False
    else:
        if word.startswith("0"):
            if len(word) >1:
                return False
        if len(word)>3:
            return False
        return True
    
def valid_variable(word, digits, letters):
    word = list(word)
    digits_in_word = set(word).intersection(set(digits))
    letters_in_word = set(word).intersection(set(letters))
    if (digits_in_word.union(letters_in_word) != set(word)):
        return False                  # foreign symbol outside letters and digits
    if (digits_in_word == set(word)):
        if len(word)<4:        # all digits but length less than 4
            return False
    return True     

def get_token_type(word, digits, letters, keywords, 
              punctuations):
    if ((word in keywords) or (word in punctuations)):
        return (word, "NULL")
    if valid_int(word, digits):
        return ("integer", word)
    if valid_variable(word, digits, letters):
        return ("variable", '0')
    else:
        return ("error", '0')

def comment_starts(wordsList):
    return wordsList.index('//')

def has_comment(wordsList):
    if '//' in wordsList:
        return True
    return False

# %%
# Just a simple initialization of the variables we will deal with

def create_symtable(word, token_type, value, symtable):
    if (value == "NULL"):
        return
    if token_type == "integer":
        return
    variables_found = [symtable[k][1] for k in range(len(symtable)) if symtable[k][0] == "variable"]
    if token_type == "variable":
        if (word in variables_found):
            return   # no need to deal with this variable again
        else:
            symtable.append(["variable", word, [0, 0], 1])  # ["TYPE","CH VALUE", "POSITION", "ORIENTATION"]
            # 1 = north, 2 = east, 3 = south, 4 = west
        
    return

# %%
def scanner(filename, symtable):  
    tuplist = []
    file = open(filename, "r")
    line_index = 0
    for line in file:
        if ('//' in line):
            idx = line.index('//')
            line = line[0:idx]
        words_in_line = line.strip().split(" ")
        if words_in_line == []:
            continue
        while(words_in_line[0] == '' or words_in_line[0] == '\t'):
            words_in_line = words_in_line[1:]
            if(len(words_in_line)) ==0:
                break
        if words_in_line == []:
            continue
        while(words_in_line[-1] == '' or words_in_line[-1] == '\t'):
            n = len(words_in_line)
            words_in_line = words_in_line[0:n]
        line_index +=1
        for word in words_in_line:
            if word == "":
                continue
            word = word.lower()
            (token_type, value) = get_token_type(word, digits, letters, keywords, punctuations)
            if token_type == "error":
                print("error on line: ", line_index, "on word: ", word, " with value: ", value)
                print(words_in_line)
                return
            else:
                if token_type == "intger":
                    word = int(word)
                tuplist.append((token_type, word)) # a list of the vaild tokens and their characters one by one
                create_symtable(word, token_type, value, symtable) # Throw this information away for now
    return tuplist

# %%
def refine_strList(strList, specials, shorthands):
    inputStr = ''
    for item in strList:
        if item not in specials:
            inputStr += item[0]
        else:
            i = specials.index(item)
            inputStr += shorthands[i]
    return inputStr

# %%
# Has 5 fields -- maximum number of variables or terminals on the RHS of a production rule
# node.name is the first attribute and identifies the type of node
# Typically, 5th attribute (node.four) has a reference to another node
class Node(object):
    def __init__(self, name = "null", one = "null", two = "null", three = "null", four = "null"):
        self._name = name
        self._one = one
        self._two = two
        self._three = three
        self._four = four
        
    @property
    def name(self):
        return self._name
    @property
    def one(self):
        return self._one
    @property
    def two(self):
        return self._two
    @property
    def three(self):
        return self._three
    @property
    def four(self):
        return self._four
    
    @name.setter
    def name(self, value):
        self._name = value
    @one.setter
    def one(self, value):
        self._one = value
    @two.setter
    def two(self, value):
        self._two = value
    @three.setter
    def three(self, value):
        self._three = value
    @four.setter
    def four(self, value):
        self._four = value

# %%
''' Return: a node object
    Parameters: two empty nodes objects: LHS and RHS, and a list of 'attributes' that are added to RHS node, and 
    then a reference from LHS is made to RHS through its fourth field
'''
def buildNode(LHS, RHS, attributes):      # RHS node is to be popped off the stack
    if ';' in attributes:
        attributes.remove(';')
    n = len(attributes)
    if n>5:
        print("6 attribute node found: ", attributes)
    for i in range(n):
        attribute = attributes[i]        # First build the RHS node, then set it as the rightmost field of LHS node 
        if i==0:
            RHS.name = attribute
        elif i==1:
            RHS.one = attribute
        elif i ==2:
            RHS.two = attribute
        elif i ==3:
            RHS.three = attribute
        elif i ==4:
            RHS.four = attribute
        #node.add_attribute(i, attribute)
        if (i== (n-1)):
            print("My fields are the following: ")
            print(RHS.name)
            print(RHS.one)
            print(RHS.two)
            print(RHS.three)
            print(RHS.four)
    if (RHS.name in ["cat", "mouse", "hole", "move", "clockwise", "repeat"]):
        LHS.name = "statement"
    elif (RHS.name in ["north", "east", "south", "west"]):
        LHS.name = RHS.name
    elif (RHS.name == "size"):
        LHS.name = "program"
    elif (RHS.name in ["sequenceNode", "statement"]):
        LHS.name = "sequenceNode"
    elif type(RHS.name) is Node:
        LHS.name = "sequenceNode"
    LHS.four = RHS
    return LHS

# %%
'''Return: None
    Parameters: 2 stacks: the ststack building nested nodes, the 'vis_stack' to help visualize node building
    Updates the ststack to build program node, "semi bottom-up"
'''
def updateSTstack(ststack, vis_stack, org_vals, RHSnode, rule_num, ruleToVar):
    print("Original values: ", org_vals)
    if ("".join(RHSnode) == ruleToVar[rule_num][1]):
        #LHS = ruleToVar[rule_num][0]
        LHSnode = Node()
        RHSnode = Node()
        LHSnode = buildNode(LHSnode, RHSnode, org_vals)
        print("Found rule to RHS variable correspondence! Can use it to decide type of Node")
        vis_stack.append(ruleToVar[rule_num][0])
        ststack.append(LHSnode)
        print("LHS node is of type: ", LHSnode.name)
    print("STstack: ", ststack)
    print("vis stack: ", vis_stack)
    return

# %%
# More global variables

LRtable = LRtable2[1:]
lookaheads = LRtable2[0]
#print(lookaheads)

ruleToVar = [('P*','P'), ('P', 'ziibLt'), ('L', 'S;'), ('L', 'LS;'), ('S', 'cviiD'), 
             ('S', 'mviiD'), ('S', 'hii'), ('S', 'ov'), ('S', 'ovi'), ('S', 'lv'), ('S', 'riLd'),
             ('D', 'n'), ('D', 's'), ('D', 'e'), ('D', 'w')]
rulestack = []

# %%
def handleNextEntry(state, inputStr, tokenidx, stack, rulestack, ststack, vis_stack, wordList):
    lookahead = '$'
    org_word = ""
    if tokenidx<len(inputStr):
        lookahead = inputStr[tokenidx]
        org_word = wordList[tokenidx]
    lookahead_index = lookaheads.index(lookahead)
    entry = LRtable[state][lookahead_index]
    if entry == '':
        print("blank entry on this lookahead = ", lookahead, " with state = ",state, " breaking")
        print("##INVALID program##")
        return
    if entry.startswith('s'):
        stack.append(lookahead)
        ststack.append(org_word)
        vis_stack.append(org_word)
        
        next_state = int(entry[1:])
        stack.append(next_state)
        handleNextEntry(next_state, inputStr, tokenidx+1, stack, rulestack, ststack, vis_stack, wordList)
    elif entry.startswith('r'):
        rule_num = int(entry[1:])
        RHSvar = ruleToVar[rule_num][1]
        LHSvar = ruleToVar[rule_num][0]
        rulestack.append([rule_num, LHSvar, RHSvar])
        print("popping using reduction rule number: ", rule_num, " rule: ", LHSvar, " -> ", RHSvar, " Stack contents: ", stack)
        RHSnode = []
        org_vals = []
        for i in range(2*len(RHSvar)):
            if(i%2!=0):
                val = stack.pop()
                RHSnode.insert(0, val)
                continue
            org_val = ststack.pop()
            vis_stack.pop()
            org_vals.insert(0, org_val)
            stack.pop()
        updateSTstack(ststack, vis_stack, org_vals, RHSnode, rule_num, ruleToVar)
        next_state = int(stack[-1])            # before I push the LHS variable, mark which state I was last in
        stack.append(LHSvar)
        lookahead = stack[-1]
        lookahead_index = lookaheads.index(lookahead)
        entry = LRtable[next_state][lookahead_index] 
        stack.append(entry)   
        next_state = int(stack[-1])
        #print("final state of stack after reduction and pushing variable and new state: ", stack)
        handleNextEntry(next_state, inputStr, tokenidx, stack, rulestack, ststack, vis_stack, wordList)
    elif entry == 'acc':
        print("lookahead is $, stack contents = ", stack, " and entry is ", entry, " so, accept")
        print ("*** VALID PROGRAM ***: program-string can be derived using the grammar")
        #print("with rulestack: " , rulestack)
        # print("with original stack: " , org_stack)
        return ststack
    else:
        print("Encountered blank entry with stack = ", stack, "lookahead ", lookahead, "entry: ", entry )
        print ("*** INVALID PROGRAM ***: not syntactically correct")
    return

# %%
## Set up input files and global parameters -- my files are in a folder called 'dataproj2'. Change to "" if in same folder

filepath = "dataproj2/"
#filepath = input("Please enter a filepath + "/", (empty string if same directory as this file): ")

keywords = ["begin", "halt","cat", "mouse", "clockwise", "move", "north", "south", "east", "west", "hole", 
          "repeat", "size", "end"]
punctuations = [";"]               
letters = list("abcdefghijklmnopqrstuvwxyz")
digits = list("0123456789")
specials = ['size', 'move', 'clockwise', 'end', 'halt']
shorthands = ['z', 'o', 'l', 'd', 't']

filename = input("Please enter a filename, (e.g. sample1.mc/ sample2.mc): ")
filename2 = filepath + filename
# Out:
# Please enter a filename, (e.g. sample1.mc/ sample2.mc): sample1.mc

# %%
# Same as in project 2
def parser(filename, rulestack, ststack, vis_stack, symtable):
    tuplist = scanner(filename, symtable)
    inputStr = ''
    wordList = []
    if tuplist != []:     
        strList = [tuplist[k][0] for k in range(len(tuplist))] # tupilist[1] is the word in line encountered
        wordList = [tuplist[k][1] for k in range(len(tuplist))]
        inputStr = refine_strList(strList, specials, shorthands)
    else:
        print("INVALID program: has invalid tokens")
    print(inputStr)
    stack = []
    state = 0
    stack.append(state)
    tokenidx = 0
    ststack = handleNextEntry(state, inputStr, tokenidx, stack, rulestack, ststack, vis_stack, wordList)
    return wordList

# %%
ststack = []   #st stack will have 1 item at the end: a "program node" with references to all program statements
symtable = []
vis_stack = []
wordList = parser(filename2, rulestack, ststack, vis_stack, symtable)    ## SECOND RUN
# Out:
# ziibmviin;lv;cviiw;rilv;d;cviis;hii;ov;ovi;ovi;rilv;d;ovi;lv;ovi;ovi;rilv;d;ovi;ovi;lv;riov;ov;d;t
# popping using reduction rule number:  11  rule:  D  ->  n  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'n', 33]
# Original values:  ['north']
# My fields are the following:
# north
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  north
# STstack:  ['size', '40', '40', 'begin', 'mouse', 'jerry', '10', '10', <__main__.Node object at 0x000001ECE6889EC8>]
# vis stack:  ['size', '40', '40', 'begin', 'mouse', 'jerry', '10', '10', 'D']
# popping using reduction rule number:  5  rule:  S  ->  mviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'm', 9, 'v', 18, 'i', 25, 'i', 30, 'D', '37']
# Original values:  ['mouse', 'jerry', '10', '10', <__main__.Node object at 0x000001ECE6889EC8>]
# My fields are the following:
# mouse
# jerry
# 10
# 10
# <__main__.Node object at 0x000001ECE6889EC8>
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68A8848>]
# vis stack:  ['size', '40', '40', 'begin', 'S']
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'S', '7', ';', 16]
# Original values:  [<__main__.Node object at 0x000001ECE68A8848>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE68A8848>
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68A88C8>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'jerry']
# My fields are the following:
# clockwise
# jerry
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68A88C8>, <__main__.Node object at 0x000001ECE68A8708>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE68A88C8>, <__main__.Node object at 0x000001ECE68A8708>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE68A88C8>
# <__main__.Node object at 0x000001ECE68A8708>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE688B5C8>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  14  rule:  D  ->  w  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'w', 36]
# Original values:  ['west']
# My fields are the following:
# west
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  west
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE688B5C8>, 'cat', 'tom', '30', '30', <__main__.Node object at 0x000001ECE688B708>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'cat', 'tom', '30', '30', 'D']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D', '32']
# Original values:  ['cat', 'tom', '30', '30', <__main__.Node object at 0x000001ECE688B708>]
# My fields are the following:
# cat
# tom
# 30
# 30
# <__main__.Node object at 0x000001ECE688B708>
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE688B5C8>, <__main__.Node object at 0x000001ECE688BE88>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE688B5C8>, <__main__.Node object at 0x000001ECE688BE88>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE688B5C8>
# <__main__.Node object at 0x000001ECE688BE88>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE688B2C8>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'tom']
# My fields are the following:
# clockwise
# tom
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE688B2C8>, 'repeat', '3', <__main__.Node object at 0x000001ECE688B388>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'repeat', '3', 'S']
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7', ';', 16]
# Original values:  [<__main__.Node object at 0x000001ECE688B388>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE688B388>
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE688B2C8>, 'repeat', '3', <__main__.Node object at 0x000001ECE67434C8>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'repeat', '3', 'L']
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'd', 31]
# Original values:  ['repeat', '3', <__main__.Node object at 0x000001ECE67434C8>, 'end']
# My fields are the following:
# repeat
# 3
# <__main__.Node object at 0x000001ECE67434C8>
# end
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE688B2C8>, <__main__.Node object at 0x000001ECE6743BC8>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE688B2C8>, <__main__.Node object at 0x000001ECE6743BC8>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE688B2C8>
# <__main__.Node object at 0x000001ECE6743BC8>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68A2908>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  12  rule:  D  ->  s  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 's', 34]
# Original values:  ['south']
# My fields are the following:
# south
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  south
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68A2908>, 'cat', 'sylvester', '30', '10', <__main__.Node object at 0x000001ECE68A2DC8>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'cat', 'sylvester', '30', '10', 'D']
# popping using reduction rule number:  4  rule:  S  ->  cviiD  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'c', 8, 'v', 17, 'i', 24, 'i', 29, 'D', '32']
# Original values:  ['cat', 'sylvester', '30', '10', <__main__.Node object at 0x000001ECE68A2DC8>]
# My fields are the following:
# cat
# sylvester
# 30
# 10
# <__main__.Node object at 0x000001ECE68A2DC8>
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68A2908>, <__main__.Node object at 0x000001ECE6888608>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE68A2908>, <__main__.Node object at 0x000001ECE6888608>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE68A2908>
# <__main__.Node object at 0x000001ECE6888608>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6888448>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  6  rule:  S  ->  hii  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'h', 10, 'i', 19, 'i', 26]
# Original values:  ['hole', '20', '20']
# My fields are the following:
# hole
# 20
# 20
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6888448>, <__main__.Node object at 0x000001ECE6888288>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE6888448>, <__main__.Node object at 0x000001ECE6888288>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE6888448>
# <__main__.Node object at 0x000001ECE6888288>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6888D88>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20]
# Original values:  ['move', 'jerry']
# My fields are the following:
# move
# jerry
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6888D88>, <__main__.Node object at 0x000001ECE6888588>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE6888D88>, <__main__.Node object at 0x000001ECE6888588>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE6888D88>
# <__main__.Node object at 0x000001ECE6888588>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68755C8>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20, 'i', 27]
# Original values:  ['move', 'jerry', '19']
# My fields are the following:
# move
# jerry
# 19
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68755C8>, <__main__.Node object at 0x000001ECE6887348>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE68755C8>, <__main__.Node object at 0x000001ECE6887348>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE68755C8>
# <__main__.Node object at 0x000001ECE6887348>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6887C88>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20, 'i', 27]
# Original values:  ['move', 'tom', '15']
# My fields are the following:
# move
# tom
# 15
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6887C88>, <__main__.Node object at 0x000001ECE68871C8>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE6887C88>, <__main__.Node object at 0x000001ECE68871C8>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE6887C88>
# <__main__.Node object at 0x000001ECE68871C8>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6887BC8>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'jerry']
# My fields are the following:
# clockwise
# jerry
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6887BC8>, 'repeat', '2', <__main__.Node object at 0x000001ECE6887048>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'repeat', '2', 'S']
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7', ';', 16]
# Original values:  [<__main__.Node object at 0x000001ECE6887048>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE6887048>
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6887BC8>, 'repeat', '2', <__main__.Node object at 0x000001ECE6887E08>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'repeat', '2', 'L']
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'd', 31]
# Original values:  ['repeat', '2', <__main__.Node object at 0x000001ECE6887E08>, 'end']
# My fields are the following:
# repeat
# 2
# <__main__.Node object at 0x000001ECE6887E08>
# end
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6887BC8>, <__main__.Node object at 0x000001ECE68877C8>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE6887BC8>, <__main__.Node object at 0x000001ECE68877C8>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE6887BC8>
# <__main__.Node object at 0x000001ECE68877C8>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6887608>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20, 'i', 27]
# Original values:  ['move', 'jerry', '20']
# My fields are the following:
# move
# jerry
# 20
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6887608>, <__main__.Node object at 0x000001ECE6886088>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE6887608>, <__main__.Node object at 0x000001ECE6886088>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE6887608>
# <__main__.Node object at 0x000001ECE6886088>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6886F48>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'tom']
# My fields are the following:
# clockwise
# tom
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6886F48>, <__main__.Node object at 0x000001ECE6886488>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE6886F48>, <__main__.Node object at 0x000001ECE6886488>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE6886F48>
# <__main__.Node object at 0x000001ECE6886488>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68869C8>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20, 'i', 27]
# Original values:  ['move', 'sylvester', '10']
# My fields are the following:
# move
# sylvester
# 10
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68869C8>, <__main__.Node object at 0x000001ECE68863C8>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE68869C8>, <__main__.Node object at 0x000001ECE68863C8>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE68869C8>
# <__main__.Node object at 0x000001ECE68863C8>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6882288>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20, 'i', 27]
# Original values:  ['move', 'tom', '10']
# My fields are the following:
# move
# tom
# 10
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6882288>, <__main__.Node object at 0x000001ECE6829F88>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE6882288>, <__main__.Node object at 0x000001ECE6829F88>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE6882288>
# <__main__.Node object at 0x000001ECE6829F88>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6880B88>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'tom']
# My fields are the following:
# clockwise
# tom
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6880B88>, 'repeat', '3', <__main__.Node object at 0x000001ECE68855C8>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'repeat', '3', 'S']
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7', ';', 16]
# Original values:  [<__main__.Node object at 0x000001ECE68855C8>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE68855C8>
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6880B88>, 'repeat', '3', <__main__.Node object at 0x000001ECE6888088>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'repeat', '3', 'L']
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'd', 31]
# Original values:  ['repeat', '3', <__main__.Node object at 0x000001ECE6888088>, 'end']
# My fields are the following:
# repeat
# 3
# <__main__.Node object at 0x000001ECE6888088>
# end
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6880B88>, <__main__.Node object at 0x000001ECE6888388>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE6880B88>, <__main__.Node object at 0x000001ECE6888388>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE6880B88>
# <__main__.Node object at 0x000001ECE6888388>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6888C48>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20, 'i', 27]
# Original values:  ['move', 'tom', '10']
# My fields are the following:
# move
# tom
# 10
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE6888C48>, <__main__.Node object at 0x000001ECE688A808>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE6888C48>, <__main__.Node object at 0x000001ECE688A808>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE6888C48>
# <__main__.Node object at 0x000001ECE688A808>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE686CE48>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  8  rule:  S  ->  ovi  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'o', 11, 'v', 20, 'i', 27]
# Original values:  ['move', 'jerry', '5']
# My fields are the following:
# move
# jerry
# 5
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE686CE48>, <__main__.Node object at 0x000001ECE6886788>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE686CE48>, <__main__.Node object at 0x000001ECE6886788>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE686CE48>
# <__main__.Node object at 0x000001ECE6886788>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68AC1C8>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  9  rule:  S  ->  lv  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'l', 12, 'v', 21]
# Original values:  ['clockwise', 'tom']
# My fields are the following:
# clockwise
# tom
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68AC1C8>, <__main__.Node object at 0x000001ECE68AC348>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE68AC1C8>, <__main__.Node object at 0x000001ECE68AC348>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE68AC1C8>
# <__main__.Node object at 0x000001ECE68AC348>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68AC488>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'o', 11, 'v', 20]
# Original values:  ['move', 'sylvester']
# My fields are the following:
# move
# sylvester
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68AC488>, 'repeat', '10', <__main__.Node object at 0x000001ECE68AC708>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'repeat', '10', 'S']
# popping using reduction rule number:  2  rule:  L  ->  S;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'S', '7', ';', 16]
# Original values:  [<__main__.Node object at 0x000001ECE68AC708>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE68AC708>
# null
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68AC488>, 'repeat', '10', <__main__.Node object at 0x000001ECE68AC948>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'repeat', '10', 'L']
# popping using reduction rule number:  7  rule:  S  ->  ov  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'o', 11, 'v', 20]
# Original values:  ['move', 'tom']
# My fields are the following:
# move
# tom
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68AC488>, 'repeat', '10', <__main__.Node object at 0x000001ECE68AC948>, <__main__.Node object at 0x000001ECE68ACB48>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'repeat', '10', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE68AC948>, <__main__.Node object at 0x000001ECE68ACB48>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE68AC948>
# <__main__.Node object at 0x000001ECE68ACB48>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68AC488>, 'repeat', '10', <__main__.Node object at 0x000001ECE68ACD08>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'repeat', '10', 'L']
# popping using reduction rule number:  10  rule:  S  ->  riLd  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'r', 13, 'i', 22, 'L', '28', 'd', 31]
# Original values:  ['repeat', '10', <__main__.Node object at 0x000001ECE68ACD08>, 'end']
# My fields are the following:
# repeat
# 10
# <__main__.Node object at 0x000001ECE68ACD08>
# end
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  statement
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68AC488>, <__main__.Node object at 0x000001ECE68ACE08>]
# vis stack:  ['size', '40', '40', 'begin', 'L', 'S']
# popping using reduction rule number:  3  rule:  L  ->  LS;  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 'S', '15', ';', 23]
# Original values:  [<__main__.Node object at 0x000001ECE68AC488>, <__main__.Node object at 0x000001ECE68ACE08>, ';']
# My fields are the following:
# <__main__.Node object at 0x000001ECE68AC488>
# <__main__.Node object at 0x000001ECE68ACE08>
# null
# null
# null
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  sequenceNode
# STstack:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68ACFC8>]
# vis stack:  ['size', '40', '40', 'begin', 'L']
# popping using reduction rule number:  1  rule:  P  ->  ziibLt  Stack contents:  [0, 'z', 2, 'i', 3, 'i', 4, 'b', 5, 'L', '6', 't', 14]
# Original values:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68ACFC8>, 'halt']
# 6 attribute node found:  ['size', '40', '40', 'begin', <__main__.Node object at 0x000001ECE68ACFC8>, 'halt']
# My fields are the following:
# size
# 40
# 40
# begin
# <__main__.Node object at 0x000001ECE68ACFC8>
# Found rule to RHS variable correspondence! Can use it to decide type of Node
# LHS node is of type:  program
# STstack:  [<__main__.Node object at 0x000001ECE68ACF48>]
# vis stack:  ['P']
# lookahead is $, stack contents =  [0, 'P', '1']  and entry is  acc  so, accept
# *** VALID PROGRAM ***: program-string can be derived using the grammar

# %%
def direction_number(direction):  # directions = ["north =1", "east = 2", "south = 3", "west =4"]
    if direction == "north":
        return 1
    if direction == "east":
        return 2
    if direction == "south":
        return 3
    if direction == "west":
        return 4

# %%
def addMovement(node, prev_position, new_position, statement_list, symtable): # of form moveRelative c3 -5 0
    result = check_same_position(node, new_position, symtable)
    # first display them on the same square anyway
    varname = node.one
    xoffset = (int(scale_factor))*(new_position[0] - prev_position[0])
    yoffset = -1*((int(scale_factor)))*(new_position[1] - prev_position[1])   # -1 because JSAWAA interprets (0,30) as 30 units south!
    command = "moveRelative " + varname + " " + str(xoffset) + " " + str(yoffset)
    statement_list.append(command)
    
    if result == "don't continue":   # then delete them
        more_command = "remove " + varname
        statement_list.append(command)
        print("removed something")
    print("prev_position: ", prev_position, "new_position ", new_position)
    return
    #print("calculated offsets:(x,y) ", xoffset, " ", yoffset)

# %%
def check_same_position(node, new_pos, symtable):                      
    all_pos = [symtable[k][2] for k in range(len(symtable))]  # all positions in symtable 
    for i in range(len(all_pos)):
        if new_pos != [0,0] and new_pos == all_pos[i]:# if at least once this new position matches with another position already in symtable
            idx = i                               # index of other creature with new position
            if node.one != symtable[idx][1]:      # but not itself
                print("Something about to step on the same square as another!")# then we should get to this print, but I never did!
                if node.name == "cat" and symtable[idx][0] == "cat":
                    var = node.one
                    vars_found = [symtable[k][1] for k in range(len(symtable))]
                    cat_idx = vars_found.index(var)
                    symtable[cat_idx][1] = "REMOVED CAT"
                    print("REMOVED A CAT! SAME POSITION")
                    return "don't continue"
                elif node.name == "mouse" and symtable[idx][0] == "mouse":
                    hole_positions = [symtable[k][2] for k in range(len(symtable)) if symtable[k][0] == "hole"]
                    if new_pos in hole_positions:
                        return "continue"
                    var = node.one    # otherwise not in a hole
                    vars_found = [symtable[k][1] for k in range(len(symtable))]
                    mouse_idx = vars_found.index(var)
                    symtable[mouse_idx][1] = "REMOVED MOUSE"     # remove this mouse, not the other one
                    print("REMOVED A MOUSE! SAME POSITION")
                    return "don't continue"
                else:  # cat and mouse in same position
                    if node.name == "cat":    # then remove the mouse
                        symtable[idx][1] = "REMOVED MOUSE"
                        print("REMOVED A MOUSE! CAT ATE IT!")
                        return "don't continue"
                    else:# this var is a mouse, needs to be removed
                        var = node.one
                        vars_found = [symtable[k][1] for k in range(len(symtable))]
                        mouse_idx = vars_found.index(var)
                        symtable[mouse_idx][1] = "REMOVED MOUSE"
                        return "don't continue"
                        print("REMOVED A MOUSE! RAN INTO A CAT")
                    
    return "continue"

# %%
def addCatorMouse(node, statement_list, symtable):             # of form circle c6 205 61 7 black transparent
    resized_two = int(scale_factor)*(int(node.two))
    resized_three = int(scale_factor)*(int(node.three))
    command = "circle " + node.one + " " + str(resized_two) + " " + str(resized_three) + " "
    if node.name == "cat":
        command += str(15)    #diam = 15
        command += " black yellow"
    else:
        command += str(6)    #diam = 15
        command += " black blue"
    statement_list.append(command)
    
    # Update "variable in symtable to cat or mouse"
    vars_found = [symtable[k][1] for k in range(len(symtable))]
    var_idx = vars_found.index(node.one)    # var name
    symtable[var_idx][0] = node.name    # set variable to cat or mouse
    return

# %%
def addHole(node, statement_list, symtable):         # of form rectangle c6 205 61 7 10 black transparent
    holename = str(node.one)+str(node.two)
    symtable.append(["hole", holename, [int(node.one), int(node.two)], 0])  # hole same no direction
    
    resized_two = str(int(scale_factor)*(int(node.one)))
    resized_three = str(int(scale_factor)*(int(node.two)))
    command = "rectangle " + holename + " " + resized_two + " " + resized_three + " " + str(15) + " " + str(15) + " black black"
    statement_list.append(command)
    return

# %%
def JSAWAA_line(symtable, node, statement_list):
    x = int(node.one)
    y = int(node.two)
    for i in range(x):
        step = 15*i
        line = "line hline" +str(i)+ " 0 " + str(step) + " " + str(700) + " " + str(step) + " black"    # line hline2 0 20 450 20 black 
        statement_list.append(line)
        if i*15>800:
            break
    for j in range(y):
        step = 15*j
        line = "line vline" +str(j)+ " "+ str(step) + " 0 " + str(step) + " 600 black"
        statement_list.append(line)
        if j*15>800:
            break
    return

# %%
def update_symtable(symtable, node, statement_list):
    if node.name in ["cat", "mouse"]:
        print("Found cat or mouse node!")
        addCatorMouse(node, statement_list, symtable)
        var = node.one
        vars_found = [symtable[k][1] for k in range(len(symtable))]
        var_idx = vars_found.index(var)
        symtable[var_idx][2] = [int(node.two), int(node.three)]   # var two and three are initial cat and mouse positions
        direction = node.four.name    # orientation node is in var.four
        dir_num = direction_number(direction)
        symtable[var_idx][3] = dir_num
        #print(symtable)
    if node.name == "hole":
        print("Just need to put a hole at position x = : ", node.one, ", y = ", node.two, "!")
        addHole(node, statement_list, symtable)
    if node.name == "size":
        print("Just need to draw a grid of size x = : ", node.one, ", y = ", node.two, "!")
        JSAWAA_line(symtable, node, statement_list)
    if node.name =="clockwise":
        print("Found clockwise node!")
        var = node.one
        vars_found = [symtable[k][1] for k in range(len(symtable))]
        if var not in vars_found:
            print("Error, this cat or mouse has been removed before")
            return
        var_idx = vars_found.index(var)
        symtable[var_idx][3] +=1
        symtable[var_idx][3] = (symtable[var_idx][3])%4
        #print("current list of locations in table: ", [symtable[k][2] for k in range(len(symtable))])
    if node.name == "move":
        print("Found move node!")
        print("current list of locations in table: ", [symtable[k][2] for k in range(len(symtable))])
        var = node.one
        vars_found = [symtable[k][1] for k in range(len(symtable))]
        if var not in vars_found:
            print("Error, this cat or mouse has been removed before")
            return
        var_idx = vars_found.index(var)
        prev_position = symtable[var_idx][2].copy()
        dir_num = symtable[var_idx][3]        # need to move in this direction
        if node.two == "null":
            if (dir_num %2)==0:             #east, west are 0 mod 2; north,south are 1 mod 2; 
                if (dir_num ==2):
                    symtable[var_idx][2][0] +=1    # east
                else:
                    symtable[var_idx][2][0] -=1    # west
            else:
                if (dir_num ==1):
                    symtable[var_idx][2][1] +=1    # north
                else:
                    symtable[var_idx][2][1] -=1    # south
        else:
            if (dir_num %2)==0:             #east, west are 0 mod 2; north,south are 1 mod 2; 
                if (dir_num ==2):
                    symtable[var_idx][2][0] +=int(node.two)    # east
                else:
                    symtable[var_idx][2][0] -=int(node.two)   # west
            else:
                if (dir_num ==1):
                    symtable[var_idx][2][1] +=int(node.two)    # north
                else:
                    symtable[var_idx][2][1] -=int(node.two)    # south
        new_position = symtable[var_idx][2]
        addMovement(node, prev_position, new_position, statement_list, symtable)
        #print(symtable)
    return

# %%
def traverse(symtable, node, statement_list):
    a = node.name
    b = node.one
    c = node.two
    d = node.three
    e = node.four
    #print(a, b, c, d, e)
    if type(a) is Node:
        if a.name == "repeat":
            print("#####Found repeat node!: ", a.one, " many times")
            for i in range(int(a.one)):   # a.one = how many times to repeat
                update_symtable(symtable, a.two, statement_list)
                traverse(symtable, a.two, statement_list)
        else:
            update_symtable(symtable, a, statement_list)
            traverse(symtable, a, statement_list)
    if type(b) is Node:
        if b.name == "repeat":
            print("#####Found repeat node: ", b.one, " many times")
            for i in range(int(b.one)):   # a.one = how many times to repeat
                update_symtable(symtable, b.two, statement_list)
                traverse(symtable, b.two, statement_list)
        else:
            update_symtable(symtable, b, statement_list)
            traverse(symtable, b, statement_list)
    if type(c) is Node:
        if c.name == "repeat":
            print("#####Found repeat node: ", c.one, " many times")
            for i in range(int(c.one)):   # a.one = how many times to repeat
                update_symtable(symtable, c.two, statement_list)
                traverse(symtable, c.two, statement_list)
        else:
            update_symtable(symtable, c, statement_list)
            traverse(symtable, c, statement_list)
    if type(d) is Node:
        if d.name == "repeat":
            print("#####Found repeat node: ", d.one, " many times")
            for i in range(int(d.one)):   # a.one = how many times to repeat
                update_symtable(symtable, d.two, statement_list)
                traverse(symtable, d.two, statement_list)
        else:
            update_symtable(symtable, d, statement_list)
            traverse(symtable, d, statement_list)
    if type(e) is Node:
        if e.name == "repeat":
            print("#####Found repeat node: ", e.one, " many times")
            for i in range(int(e.one)):   # a.one = how many times to repeat
                update_symtable(symtable, e.two, statement_list)
                traverse(symtable, e.two, statement_list)
        else:
            update_symtable(symtable, e, statement_list)
            traverse(symtable, e, statement_list)
    else:
        return

# %%
node = ststack[0]                                                             ### THIRD/FINAL RUN
statement_list = []
scale_factor = input("Please enter a SCALE FACTOR to scale movements of cat and mice: ") # CHANGE THIS DEPENDING ON THE PROGRAM!
traverse(symtable, node, statement_list)
# Out:
# Please enter a SCALE FACTOR to scale movements of cat and mice: 10
# Just need to draw a grid of size x = :  40 , y =  40 !
# Found cat or mouse node!
# Found clockwise node!
# Found cat or mouse node!
# #####Found repeat node:  3  many times
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found cat or mouse node!
# Just need to put a hole at position x = :  20 , y =  20 !
# Found move node!
# current list of locations in table:  [[10, 10], [30, 30], [30, 10], [20, 20]]
# prev_position:  [10, 10] new_position  [11, 10]
# Found move node!
# current list of locations in table:  [[11, 10], [30, 30], [30, 10], [20, 20]]
# Something about to step on the same square as another!
# removed something
# prev_position:  [11, 10] new_position  [30, 10]
# Found move node!
# current list of locations in table:  [[30, 10], [30, 30], [30, 10], [20, 20]]
# prev_position:  [30, 30] new_position  [30, 15]
# #####Found repeat node:  2  many times
# Found clockwise node!
# Error, this cat or mouse has been removed before
# Found clockwise node!
# Error, this cat or mouse has been removed before
# Found move node!
# current list of locations in table:  [[30, 10], [30, 15], [30, 10], [20, 20]]
# Error, this cat or mouse has been removed before
# Found clockwise node!
# Found move node!
# current list of locations in table:  [[30, 10], [30, 15], [30, 10], [20, 20]]
# prev_position:  [30, 10] new_position  [30, 0]
# Found move node!
# current list of locations in table:  [[30, 10], [30, 15], [30, 0], [20, 20]]
# prev_position:  [30, 15] new_position  [20, 15]
# #####Found repeat node:  3  many times
# Found clockwise node!
# Found clockwise node!
# Found clockwise node!
# Found move node!
# current list of locations in table:  [[30, 10], [20, 15], [30, 0], [20, 20]]
# prev_position:  [20, 15] new_position  [20, 5]
# Found move node!
# current list of locations in table:  [[30, 10], [20, 5], [30, 0], [20, 20]]
# Error, this cat or mouse has been removed before
# Found clockwise node!
# #####Found repeat node:  10  many times
# Found move node!
# current list of locations in table:  [[30, 10], [20, 5], [30, 0], [20, 20]]
# prev_position:  [30, 0] new_position  [30, -1]
# Found move node!
# current list of locations in table:  [[30, 10], [20, 5], [30, -1], [20, 20]]
# prev_position:  [20, 5] new_position  [19, 5]
# Found move node!
# current list of locations in table:  [[30, 10], [19, 5], [30, -1], [20, 20]]
# prev_position:  [30, -1] new_position  [30, -2]
# Found move node!
# current list of locations in table:  [[30, 10], [19, 5], [30, -2], [20, 20]]
# prev_position:  [19, 5] new_position  [18, 5]
# Found move node!
# current list of locations in table:  [[30, 10], [18, 5], [30, -2], [20, 20]]
# prev_position:  [30, -2] new_position  [30, -3]
# Found move node!
# current list of locations in table:  [[30, 10], [18, 5], [30, -3], [20, 20]]
# prev_position:  [18, 5] new_position  [17, 5]
# Found move node!
# current list of locations in table:  [[30, 10], [17, 5], [30, -3], [20, 20]]
# prev_position:  [30, -3] new_position  [30, -4]
# Found move node!
# current list of locations in table:  [[30, 10], [17, 5], [30, -4], [20, 20]]
# prev_position:  [17, 5] new_position  [16, 5]
# Found move node!
# current list of locations in table:  [[30, 10], [16, 5], [30, -4], [20, 20]]
# prev_position:  [30, -4] new_position  [30, -5]
# Found move node!
# current list of locations in table:  [[30, 10], [16, 5], [30, -5], [20, 20]]
# prev_position:  [16, 5] new_position  [15, 5]
# Found move node!
# current list of locations in table:  [[30, 10], [15, 5], [30, -5], [20, 20]]
# prev_position:  [30, -5] new_position  [30, -6]
# Found move node!
# current list of locations in table:  [[30, 10], [15, 5], [30, -6], [20, 20]]
# prev_position:  [15, 5] new_position  [14, 5]
# Found move node!
# current list of locations in table:  [[30, 10], [14, 5], [30, -6], [20, 20]]
# prev_position:  [30, -6] new_position  [30, -7]
# Found move node!
# current list of locations in table:  [[30, 10], [14, 5], [30, -7], [20, 20]]
# prev_position:  [14, 5] new_position  [13, 5]
# Found move node!
# current list of locations in table:  [[30, 10], [13, 5], [30, -7], [20, 20]]
# prev_position:  [30, -7] new_position  [30, -8]
# Found move node!
# current list of locations in table:  [[30, 10], [13, 5], [30, -8], [20, 20]]
# prev_position:  [13, 5] new_position  [12, 5]
# Found move node!
# current list of locations in table:  [[30, 10], [12, 5], [30, -8], [20, 20]]
# prev_position:  [30, -8] new_position  [30, -9]
# Found move node!
# current list of locations in table:  [[30, 10], [12, 5], [30, -9], [20, 20]]
# prev_position:  [12, 5] new_position  [11, 5]
# Found move node!
# current list of locations in table:  [[30, 10], [11, 5], [30, -9], [20, 20]]
# prev_position:  [30, -9] new_position  [30, -10]
# Found move node!
# current list of locations in table:  [[30, 10], [11, 5], [30, -10], [20, 20]]
# prev_position:  [11, 5] new_position  [10, 5]

# %%
# print(statement_list)

# %%
out_fname = "outfile_" + filename + str(scale_factor) + ".txt"    # DEPENDS ON SCALE FACTOR AND .mc PROGRAM RAN!
f = open(out_fname, "w")
for line in statement_list:
    f.write(line)
    f.write("\n")
f.close()

# %%
from tabulate import tabulate
print(tabulate(symtable, headers=["TYPE","CH VALUE", "POSITION", "ORIENTATION"]))
# Out:
# TYPE    CH VALUE       POSITION      ORIENTATION
# ------  -------------  ----------  -------------
# mouse   REMOVED MOUSE  [30, 10]                2
# cat     tom            [10, 5]                 0
# cat     sylvester      [30, -10]               3
# hole    2020           [20, 20]                0

# %% [markdown]
# ### Thank you!
